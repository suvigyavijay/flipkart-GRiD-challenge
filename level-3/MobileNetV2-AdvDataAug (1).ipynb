# %%
import csv
import math
import os
import cv2

from PIL import Image, ImageDraw, ImageEnhance
import numpy as np
import pandas as pd
from keras import Model
from keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from keras.layers import *
from keras.utils import Sequence
from keras.backend import epsilon
import keras.backend as K
from keras.optimizers import Adam
from keras.regularizers import l2

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import keras.backend as K
DATA_DIR = "images"

# 0.35, 0.5, 0.75, 1.0, 1.3, 1.4
ALPHA = 0.75

# 96, 128, 160, 192, 224
IMAGE_SIZE = 224

EPOCHS = 500
BATCH_SIZE = 32
PATIENCE = 50

MULTI_PROCESSING = True
THREADS = 20

data = pd.read_csv('training.csv')
train, test = train_test_split(data, test_size=0.1, random_state=123)

train.reset_index(inplace=True, drop=True)
test.reset_index(inplace=True, drop=True)

train.to_csv('train.csv', index=False)
test.to_csv('validation.csv', index=False)

TRAIN_CSV = "train.csv"
VALIDATION_CSV = "validation.csv"
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('validation.csv')

val_coords = np.zeros((len(df),4))
val_images = np.zeros((len(df), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)

for index, row in df.iterrows():
    path = os.path.join(DATA_DIR, row['image_name'])
    x1 = row['x1']
    x2 = row['x2']
    y1 = row['y1']
    y2 = row['y2']

    img = Image.open(path)
    width, height = img.size

    val_coords[index, 0] = x1*IMAGE_SIZE / width
    val_coords[index, 1] = y1*IMAGE_SIZE / height
    val_coords[index, 2] = (x2 - x1)* IMAGE_SIZE / width
    val_coords[index, 3] = (y2 - y1)*IMAGE_SIZE / height 
    
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE))
    img = img.convert('RGB')
    pil_img = img
    img = np.array(img, dtype=np.float32)
    val_images[index] = preprocess_input(img.copy())
    pil_img.close()

# %%
class DataGenerator(Sequence):

    def __init__(self, csv_file,rnd_rescale=True, rnd_multiply=True, rnd_color=True, rnd_crop=True, rnd_flip=True,
                 batch_size = BATCH_SIZE, rnd_dice=True):
        self.paths = []
        self.coords = []
        self.batch_size = batch_size
        self.rnd_rescale = rnd_rescale
        self.rnd_multiply = rnd_multiply
        self.rnd_color = rnd_color
        self.rnd_crop = rnd_crop
        self.rnd_flip = rnd_flip
        self.rnd_dice = rnd_dice

        with open(csv_file, "r") as file:
            self.coords = np.zeros((sum(1 for line in file)-1, 4))
            
        df = pd.read_csv(csv_file)

        for index, row in df.iterrows():
            path = os.path.join(DATA_DIR, row['image_name'])
            x1 = row['x1']
            x2 = row['x2']
            y1 = row['y1']
            y2 = row['y2']

            img = Image.open(path)
            width, height = img.size

            self.coords[index, 0] = x1
            self.coords[index, 1] = y1
            self.coords[index, 2] = x2 
            self.coords[index, 3] = y2 

            self.paths.append(path)
        
    def __len__(self):
        return math.ceil(len(self.coords)*2 / self.batch_size)

    def __getitem__(self, idx):
        batch_paths = self.paths[idx * self.batch_size//2:(idx + 1) * self.batch_size//2]
        coords = self.coords[idx * self.batch_size//2:(idx + 1) * self.batch_size//2].copy()
        batch_coords = np.zeros((self.batch_size,4))
        batch_images = np.zeros((self.batch_size, IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
        i = 0
        for j, f in enumerate(batch_paths):
            img = Image.open(f)
            x0,y0,x1,y1 = coords[j]
            image_width = img.width
            image_height = img.height
            img2 = img.resize((IMAGE_SIZE, IMAGE_SIZE))
            img2 = img2.convert('RGB')
            img2 = np.array(img2, dtype=np.float32)
            batch_images[i] = preprocess_input(img2.copy())
            
            batch_coords[i, 0] = x0 * IMAGE_SIZE / image_width
            batch_coords[i, 1] = y0 * IMAGE_SIZE / image_height
            batch_coords[i, 2] = (x1 - x0) * IMAGE_SIZE / image_width
            batch_coords[i, 3] = (y1 - y0) * IMAGE_SIZE / image_height 
            
            if self.rnd_dice:
                
                select = np.random.randint(5)
                
                if select==0 and self.rnd_rescale:
                    old_width = img.width
                    old_height = img.height

                    rescale = np.random.uniform(low=0.6, high=1.4)
                    new_width = int(old_width * rescale)
                    new_height = int(old_height * rescale)

                    img = img.resize((new_width, new_height))

                    x0 *= new_width / old_width
                    y0 *= new_height / old_height
                    x1 *= new_width / old_width
                    y1 *= new_height / old_height

                if select==1 and self.rnd_crop:
                    start_x = np.random.randint(0, high=np.floor(0.15 * img.width))
                    stop_x = img.width - np.random.randint(0, high=np.floor(0.15 * img.width))
                    start_y = np.random.randint(0, high=np.floor(0.15 * img.height))
                    stop_y = img.height - np.random.randint(0, high=np.floor(0.15 * img.height))

                    img = img.crop((start_x, start_y, stop_x, stop_y))

                    x0 = max(x0 - start_x, 0)
                    y0 = max(y0 - start_y, 0)
                    x1 = min(x1 - start_x, img.width)
                    y1 = min(y1 - start_y, img.height)

                    if np.abs(x1 - x0) < 5 or np.abs(y1 - y0) < 5:
                        print("\nWarning: cropped too much (obj width {}, obj height {}, img width {}, img height {})\n".format(x1 - x0, y1 - y0, img.width, img.height))

                if select==2 and self.rnd_flip:
                    elem = np.random.choice([0, 90, 180, 270, 1423, 1234])
                    if elem % 10 == 0:
                        x = x0 - img.width / 2
                        y = y0 - img.height / 2

                        x0 = img.width / 2 + x * np.cos(np.deg2rad(elem)) - y * np.sin(np.deg2rad(elem))
                        y0 = img.height / 2 + x * np.sin(np.deg2rad(elem)) + y * np.cos(np.deg2rad(elem))

                        x = x1 - img.width / 2
                        y = y1 - img.height / 2

                        x1 = img.width / 2 + x * np.cos(np.deg2rad(elem)) - y * np.sin(np.deg2rad(elem))
                        y1 = img.height / 2 + x * np.sin(np.deg2rad(elem)) + y * np.cos(np.deg2rad(elem))

                        img = img.rotate(-elem)
                    else:
                        if elem == 1423:
                            img = img.transpose(Image.FLIP_TOP_BOTTOM)
                            y0 = img.height - y0
                            y1 = img.height - y1

                        elif elem == 1234:
                            img = img.transpose(Image.FLIP_LEFT_RIGHT)
                            x0 = img.width - x0
                            x1 = img.width - x1

                image_width = img.width
                image_height = img.height

                tmp = x0
                x0 = min(x0, x1)
                x1 = max(tmp, x1)

                tmp = y0
                y0 = min(y0, y1)
                y1 = max(tmp, y1)

                x0 = max(x0, 0)
                y0 = max(y0, 0)

                y0 = min(y0, image_height)
                x0 = min(x0, image_width)
                y1 = min(y1, image_height)
                x1 = min(x1, image_width)

                if select==3 and self.rnd_color:
                    enhancer = ImageEnhance.Color(img)
                    img = enhancer.enhance(np.random.uniform(low=0.5, high=1.5))

                    enhancer2 = ImageEnhance.Brightness(img)
                    img = enhancer.enhance(np.random.uniform(low=0.7, high=1.3))

                img = img.resize((IMAGE_SIZE, IMAGE_SIZE))
                img = img.convert('RGB')
                pil_img = img
                img = np.array(img, dtype=np.float32)
                pil_img.close()
                
                if select==4 and self.rnd_multiply:
                    img[...,0] = np.floor(np.clip(img[...,0] * np.random.uniform(low=0.8, high=1.2), 0.0, 255.0))
                    img[...,1] = np.floor(np.clip(img[...,1] * np.random.uniform(low=0.8, high=1.2), 0.0, 255.0))
                    img[...,2] = np.floor(np.clip(img[...,2] * np.random.uniform(low=0.8, high=1.2), 0.0, 255.0))

                batch_images[i+1] = preprocess_input(img.copy())

                batch_coords[i+1, 0] = x0 * IMAGE_SIZE / image_width
                batch_coords[i+1, 1] = y0 * IMAGE_SIZE / image_height
                batch_coords[i+1, 2] = (x1 - x0) * IMAGE_SIZE / image_width
                batch_coords[i+1, 3] = (y1 - y0) * IMAGE_SIZE / image_height 
                
            i+=2
            
        return batch_images, batch_coords

class Validation(Callback):
    def __init__(self, generator):
        self.generator = generator

    def on_epoch_end(self, epoch, logs):
        mse = 0
        intersections = 0
        unions = 0

        for i in range(len(self.generator)):
            batch_images, gt = self.generator[i]
            pred = self.model.predict_on_batch(batch_images)
            mse += np.linalg.norm(gt - pred, ord='fro') / pred.shape[0]

            pred = np.maximum(pred, 0)

            diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,0])
            diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,1])
            intersection = np.maximum(diff_width, 0) * np.maximum(diff_height, 0)

            area_gt = gt[:,2] * gt[:,3]
            area_pred = pred[:,2] * pred[:,3]
            union = np.maximum(area_gt + area_pred - intersection, 0)

            intersections += np.sum(intersection * (union > 0))
            unions += np.sum(union)

        iou = np.round(intersections / (unions + epsilon()), 4)
        logs["val_iou"] = iou

        mse = np.round(mse, 4)
        logs["val_mse"] = mse

        print(" - val_iou: {} - val_mse: {}".format(iou, mse))

        
class ValDataGenerator(Sequence):
    def __init__(self, csv_file, val_images, val_coords, batch_size = BATCH_SIZE):
        self.images = val_images
        self.coords = val_coords
        self.batch_size = batch_size
        
    def __len__(self):
        return math.ceil(len(self.coords) / self.batch_size)
    
    def __getitem__(self, idx):
        batch_coords = self.coords[idx * self.batch_size:(idx + 1) * self.batch_size].copy()
        batch_images = self.images[idx * self.batch_size:(idx + 1) * self.batch_size]
        return batch_images, batch_coords

def IOU(y_true, y_pred):
    diff_width = K.minimum(y_true[:,0] + y_true[:,2], y_pred[:,0] + y_pred[:,2]) - K.maximum(y_true[:,0], y_pred[:,0])
    diff_height = K.minimum(y_true[:,1] + y_true[:,3], y_pred[:,1] + y_pred[:,3]) - K.maximum(y_true[:,1], y_pred[:,1])
    intersection = K.maximum(diff_width, 0) * K.maximum(diff_height, 0)

    area_gt = y_true[:,2] * y_true[:,3]
    area_pred = y_pred[:,2] * y_pred[:,3]
    union = K.maximum(area_gt + area_pred - intersection, 0)

    #ntersection = K.sum(intersection * (union > 0))
    intersection = K.tf.where(union > 0, intersection, K.zeros_like(intersection))
    intersection = K.sum(intersection)
    union = K.sum(union)
    iou = (intersection / (union + epsilon()))
    return iou

def IOU_loss(y_true, y_pred):
    return -IOU(y_true, y_pred)

# %%
def create_model(trainable=False):
    model = MobileNetV2(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
                        include_top=False, alpha=ALPHA, weights=None)

    # to freeze layers

    for layer in model.layers:
        layer.trainable = True

    x = model.layers[-1].output
    x = AveragePooling2D(pool_size=7,data_format="channels_last")(x)

    x = Flatten()(x)
    x = Dense(256,kernel_initializer='he_normal',kernel_regularizer=l2(1e-3))(x)
    x = Dense(4,kernel_initializer='he_normal',kernel_regularizer=l2(1e-3))(x)

    return Model(inputs=model.input, outputs=x)

# %%
model = create_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 24) 648         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 24) 96          Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 24) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 24) 216         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 24) 96          expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 24) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 384         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 24)   3456        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 24)   96          block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 144)  3456        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 144)  576         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 144)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 24)   3456        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 24)   96          block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 24)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 144)  3456        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 144)  576         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 144)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 24)   3456        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 24)   96          block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 24)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 144)  3456        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 144)  576         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 144)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 144)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 144)  1296        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 144)  576         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 144)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 48)   6912        block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 48)   192         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 288)  13824       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 288)  1152        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 288)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 288)  2592        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 288)  1152        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 288)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 48)   13824       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 48)   192         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 48)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 288)  13824       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 288)  1152        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 288)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 288)  2592        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 288)  1152        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 288)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 48)   13824       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 48)   192         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 48)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 288)  13824       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 288)  1152        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 288)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 288)  2592        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 288)  1152        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 288)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 48)   13824       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 48)   192         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 48)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 288)  13824       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 288)  1152        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 288)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 288)  2592        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 288)  1152        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 288)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 72)   20736       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 72)   288         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 432)  31104       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 432)  1728        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 432)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 432)  3888        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 432)  1728        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 432)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 72)   31104       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 72)   288         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 72)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 432)  31104       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 432)  1728        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 432)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 432)  3888        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 432)  1728        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 432)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 72)   31104       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 72)   288         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 72)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 432)  31104       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 432)  1728        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 432)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 432)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 432)    3888        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 432)    1728        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 432)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 120)    51840       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 120)    480         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 720)    86400       block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 720)    2880        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 720)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 720)    6480        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 720)    2880        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 720)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 120)    86400       block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 120)    480         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 120)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 720)    86400       block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 720)    2880        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 720)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 720)    6480        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 720)    2880        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 720)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 120)    86400       block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 120)    480         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 120)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 720)    86400       block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 720)    2880        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 720)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 720)    6480        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 720)    2880        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 720)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 240)    172800      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 240)    960         block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   307200      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 1280)   0           out_relu[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1280)         0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          327936      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4)            1028        dense_1[0][0]
# ==================================================================================================
# Total params: 1,711,028
# Trainable params: 1,684,388
# Non-trainable params: 26,640
# __________________________________________________________________________________________________

# %%
train_datagen = DataGenerator(TRAIN_CSV)
validation_datagen = Validation(generator=ValDataGenerator(VALIDATION_CSV, val_images, val_coords))

# %%
# model.load_weights(WEIGHTS_FILE)

# %%
model.compile(loss="mean_absolute_error", optimizer="adam", metrics=['accuracy',IOU])

checkpoint = ModelCheckpoint("mobilenetv2-flatten-{val_iou:.2f}.h5", monitor="val_iou", verbose=1, save_best_only=True,
                             save_weights_only=True, mode="max", period=1)
stop = EarlyStopping(monitor="val_iou", patience=PATIENCE, mode="max")
reduce_lr = ReduceLROnPlateau(monitor="val_iou", factor=0.2, patience=10, min_lr=1e-7, verbose=1, mode="max")

# model.summary()

# %%
model.fit_generator(generator=train_datagen,
                    epochs=EPOCHS,
                    callbacks=[validation_datagen, reduce_lr, stop, checkpoint],
                    workers=THREADS,
                    use_multiprocessing=MULTI_PROCESSING,
                    shuffle=True,
                    verbose=1)
# Out:
# Epoch 1/500
# 508/788 [==================>...........] - ETA: 42s - loss: 4.2969 - acc: 0.9598 - IOU: 0.9047
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 542, img height 369)
#
# 788/788 [==============================] - 118s 150ms/step - loss: 4.2299 - acc: 0.9622 - IOU: 0.9067
#  - val_iou: 0.8502000000000001 - val_mse: 201.4027
#
# Epoch 00001: val_iou did not improve from 0.87880
# Epoch 2/500
# 788/788 [==============================] - 115s 146ms/step - loss: 4.0786 - acc: 0.9618 - IOU: 0.9096
#  - val_iou: 0.8544 - val_mse: 185.3677
#
# Epoch 00002: val_iou did not improve from 0.87880
# Epoch 3/500
# 410/788 [==============>...............] - ETA: 55s - loss: 4.1147 - acc: 0.9620 - IOU: 0.9082
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 519, img height 417)
#
# 788/788 [==============================] - 115s 146ms/step - loss: 4.0690 - acc: 0.9638 - IOU: 0.9084
#  - val_iou: 0.8858 - val_mse: 172.7478
#
# Epoch 00003: val_iou improved from 0.87880 to 0.88580, saving model to mobilenetv2-flatten-0.89.h5
# Epoch 4/500
# 788/788 [==============================] - 114s 145ms/step - loss: 4.0111 - acc: 0.9641 - IOU: 0.9102
#  - val_iou: 0.8771 - val_mse: 177.7503
#
# Epoch 00004: val_iou did not improve from 0.88580
# Epoch 5/500
# 178/788 [=====>........................] - ETA: 1:31 - loss: 3.8628 - acc: 0.9551 - IOU: 0.9141
# Warning: cropped too much (obj width 0.0, obj height -44.0, img width 521, img height 390)
#
# 788/788 [==============================] - 117s 149ms/step - loss: 3.9498 - acc: 0.9643 - IOU: 0.9127
#  - val_iou: 0.8884000000000001 - val_mse: 172.6704
#
# Epoch 00005: val_iou improved from 0.88580 to 0.88840, saving model to mobilenetv2-flatten-0.89.h5
# Epoch 6/500
# 491/788 [=================>............] - ETA: 43s - loss: 3.8400 - acc: 0.9659 - IOU: 0.9142
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 542, img height 369)
#
# 788/788 [==============================] - 116s 148ms/step - loss: 3.9544 - acc: 0.9652 - IOU: 0.9124
#  - val_iou: 0.8404 - val_mse: 208.56560000000002
#
# Epoch 00006: val_iou did not improve from 0.88840
# Epoch 7/500
#  89/788 [==>...........................] - ETA: 1:43 - loss: 3.6093 - acc: 0.9712 - IOU: 0.9182
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 537, img height 424)
#
# 788/788 [==============================] - 117s 148ms/step - loss: 3.9123 - acc: 0.9639 - IOU: 0.9136
#  - val_iou: 0.8323 - val_mse: 193.93990000000002
#
# Epoch 00007: val_iou did not improve from 0.88840
# Epoch 8/500
# 248/788 [========>.....................] - ETA: 1:17 - loss: 3.6395 - acc: 0.9690 - IOU: 0.9172
# Warning: cropped too much (obj width 0.0, obj height -54.0, img width 551, img height 372)
#
# 788/788 [==============================] - 114s 145ms/step - loss: 3.8340 - acc: 0.9662 - IOU: 0.9147
#  - val_iou: 0.8787 - val_mse: 178.81
#
# Epoch 00008: val_iou did not improve from 0.88840
# Epoch 9/500
# 788/788 [==============================] - 114s 144ms/step - loss: 3.7644 - acc: 0.9650 - IOU: 0.9165
#  - val_iou: 0.8857 - val_mse: 176.61020000000002
#
# Epoch 00009: val_iou did not improve from 0.88840
# Epoch 10/500
# 788/788 [==============================] - 114s 145ms/step - loss: 3.7296 - acc: 0.9632 - IOU: 0.9169
#  - val_iou: 0.8712000000000001 - val_mse: 176.38490000000002
#
# Epoch 00010: val_iou did not improve from 0.88840
# Epoch 11/500
# 788/788 [==============================] - 113s 143ms/step - loss: 3.7106 - acc: 0.9656 - IOU: 0.9174
#  - val_iou: 0.8749 - val_mse: 177.211
#
# Epoch 00011: val_iou did not improve from 0.88840
# Epoch 12/500
#  34/788 [>.............................] - ETA: 1:52 - loss: 3.3386 - acc: 0.9568 - IOU: 0.9236
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 512, img height 405)
#
# 788/788 [==============================] - 115s 146ms/step - loss: 3.6078 - acc: 0.9669 - IOU: 0.9196
#  - val_iou: 0.8895000000000001 - val_mse: 179.7313
#
# Epoch 00012: val_iou improved from 0.88840 to 0.88950, saving model to mobilenetv2-flatten-0.89.h5
# Epoch 13/500
# 788/788 [==============================] - 114s 144ms/step - loss: 3.5959 - acc: 0.9662 - IOU: 0.9190
#  - val_iou: 0.8921 - val_mse: 168.07930000000002
#
# Epoch 00013: val_iou improved from 0.88950 to 0.89210, saving model to mobilenetv2-flatten-0.89.h5
# Epoch 14/500
# 464/788 [================>.............] - ETA: 46s - loss: 3.5639 - acc: 0.9681 - IOU: 0.9201
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 617, img height 416)
#
# 788/788 [==============================] - 115s 145ms/step - loss: 3.5501 - acc: 0.9684 - IOU: 0.9200
#  - val_iou: 0.8792000000000001 - val_mse: 170.02710000000002
#
# Epoch 00014: val_iou did not improve from 0.89210
# Epoch 15/500
# 788/788 [==============================] - 114s 145ms/step - loss: 3.5337 - acc: 0.9685 - IOU: 0.9197
#  - val_iou: 0.8898 - val_mse: 156.62040000000002
#
# Epoch 00015: val_iou did not improve from 0.89210
# Epoch 16/500
# 788/788 [==============================] - 113s 144ms/step - loss: 3.5252 - acc: 0.9700 - IOU: 0.9207
#  - val_iou: 0.8761 - val_mse: 174.80280000000002
#
# Epoch 00016: val_iou did not improve from 0.89210
# Epoch 17/500
# 788/788 [==============================] - 115s 146ms/step - loss: 3.5699 - acc: 0.9671 - IOU: 0.9199
#  - val_iou: 0.8685 - val_mse: 178.58200000000002
#
# Epoch 00017: val_iou did not improve from 0.89210
# Epoch 18/500
# 788/788 [==============================] - 113s 144ms/step - loss: 3.4170 - acc: 0.9671 - IOU: 0.9235
#  - val_iou: 0.89 - val_mse: 160.08540000000002
#
# Epoch 00018: val_iou did not improve from 0.89210
# Epoch 19/500
# 788/788 [==============================] - 115s 145ms/step - loss: 3.4081 - acc: 0.9699 - IOU: 0.9233
#  - val_iou: 0.8956000000000001 - val_mse: 174.05540000000002
#
# Epoch 00019: val_iou improved from 0.89210 to 0.89560, saving model to mobilenetv2-flatten-0.90.h5
# Epoch 20/500
# 788/788 [==============================] - 114s 145ms/step - loss: 3.3800 - acc: 0.9694 - IOU: 0.9240
#  - val_iou: 0.8931 - val_mse: 166.13410000000002
#
# Epoch 00020: val_iou did not improve from 0.89560
# Epoch 21/500
# 788/788 [==============================] - 114s 145ms/step - loss: 3.3941 - acc: 0.9652 - IOU: 0.9242
#  - val_iou: 0.8912 - val_mse: 164.7544
#
# Epoch 00021: val_iou did not improve from 0.89560
# Epoch 22/500
# 173/788 [=====>........................] - ETA: 1:28 - loss: 3.2967 - acc: 0.9738 - IOU: 0.9238
# Warning: cropped too much (obj width 0.0, obj height -44.0, img width 521, img height 390)
#
# 788/788 [==============================] - 113s 144ms/step - loss: 3.3669 - acc: 0.9707 - IOU: 0.9242
#  - val_iou: 0.8613000000000001 - val_mse: 176.7935
#
# Epoch 00022: val_iou did not improve from 0.89560
# Epoch 23/500
# 788/788 [==============================] - 115s 146ms/step - loss: 3.2336 - acc: 0.9717 - IOU: 0.9272
#  - val_iou: 0.8729 - val_mse: 172.86690000000002
#
# Epoch 00023: val_iou did not improve from 0.89560
# Epoch 24/500
#  29/788 [>.............................] - ETA: 1:48 - loss: 3.1591 - acc: 0.9688 - IOU: 0.9315
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 512, img height 405)
#
# 788/788 [==============================] - 113s 144ms/step - loss: 3.2406 - acc: 0.9678 - IOU: 0.9267
#  - val_iou: 0.8947 - val_mse: 167.2079
#
# Epoch 00024: val_iou did not improve from 0.89560
# Epoch 25/500
# 788/788 [==============================] - 114s 144ms/step - loss: 3.2209 - acc: 0.9699 - IOU: 0.9270
#  - val_iou: 0.9008 - val_mse: 157.9889
#
# Epoch 00025: val_iou improved from 0.89560 to 0.90080, saving model to mobilenetv2-flatten-0.90.h5
# Epoch 26/500
# 788/788 [==============================] - 115s 146ms/step - loss: 3.1970 - acc: 0.9704 - IOU: 0.9279
#  - val_iou: 0.8818 - val_mse: 167.2144
#
# Epoch 00026: val_iou did not improve from 0.90080
# Epoch 27/500
#  98/788 [==>...........................] - ETA: 1:39 - loss: 3.0541 - acc: 0.9703 - IOU: 0.9288
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 537, img height 424)
#
# 788/788 [==============================] - 114s 145ms/step - loss: 3.1810 - acc: 0.9699 - IOU: 0.9278
#  - val_iou: 0.8984000000000001 - val_mse: 159.2062
#
# Epoch 00027: val_iou did not improve from 0.90080
# Epoch 28/500
# 788/788 [==============================] - 113s 143ms/step - loss: 3.1329 - acc: 0.9709 - IOU: 0.9293
#  - val_iou: 0.8871 - val_mse: 163.7015
#
# Epoch 00028: val_iou did not improve from 0.90080
# Epoch 29/500
# 788/788 [==============================] - 115s 146ms/step - loss: 3.1423 - acc: 0.9728 - IOU: 0.9286
#  - val_iou: 0.8919 - val_mse: 161.2168
#
# Epoch 00029: val_iou did not improve from 0.90080
# Epoch 30/500
# 788/788 [==============================] - 115s 146ms/step - loss: 3.1428 - acc: 0.9718 - IOU: 0.9281
#  - val_iou: 0.8867 - val_mse: 165.1876
#
# Epoch 00030: val_iou did not improve from 0.90080
# Epoch 31/500
# 788/788 [==============================] - 115s 146ms/step - loss: 3.0688 - acc: 0.9732 - IOU: 0.9309
#  - val_iou: 0.8953000000000001 - val_mse: 166.6339
#
# Epoch 00031: val_iou did not improve from 0.90080
# Epoch 32/500
# 788/788 [==============================] - 115s 146ms/step - loss: 3.0566 - acc: 0.9731 - IOU: 0.9300
#  - val_iou: 0.8812000000000001 - val_mse: 164.5499
#
# Epoch 00032: val_iou did not improve from 0.90080
# Epoch 33/500
#  18/788 [..............................] - ETA: 2:02 - loss: 3.1165 - acc: 0.9722 - IOU: 0.9305
# Warning: cropped too much (obj width 0.0, obj height -17.0, img width 580, img height 399)
#
# 788/788 [==============================] - 113s 144ms/step - loss: 3.0553 - acc: 0.9720 - IOU: 0.9308
#  - val_iou: 0.893 - val_mse: 161.8727
#
# Epoch 00033: val_iou did not improve from 0.90080
# Epoch 34/500
#  30/788 [>.............................] - ETA: 1:49 - loss: 2.7774 - acc: 0.9698 - IOU: 0.9372
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 512, img height 405)
#
# 788/788 [==============================] - 113s 144ms/step - loss: 3.0449 - acc: 0.9728 - IOU: 0.9303
#  - val_iou: 0.881 - val_mse: 169.9402
#
# Epoch 00034: val_iou did not improve from 0.90080
# Epoch 35/500
# 506/788 [==================>...........] - ETA: 40s - loss: 2.9647 - acc: 0.9724 - IOU: 0.9317
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 542, img height 369)
#
# 788/788 [==============================] - 114s 144ms/step - loss: 2.9954 - acc: 0.9721 - IOU: 0.9314
#  - val_iou: 0.8998 - val_mse: 159.7588
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00035: val_iou did not improve from 0.90080
# Epoch 36/500
#  33/788 [>.............................] - ETA: 1:46 - loss: 2.5737 - acc: 0.9669 - IOU: 0.9436
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 512, img height 405)
#
# 788/788 [==============================] - 114s 145ms/step - loss: 2.4697 - acc: 0.9757 - IOU: 0.9449
#  - val_iou: 0.9082 - val_mse: 153.6468
#
# Epoch 00036: val_iou improved from 0.90080 to 0.90820, saving model to mobilenetv2-flatten-0.91.h5
# Epoch 37/500
# 788/788 [==============================] - 114s 145ms/step - loss: 2.3008 - acc: 0.9769 - IOU: 0.9477
#  - val_iou: 0.9065000000000001 - val_mse: 153.1946
#
# Epoch 00037: val_iou did not improve from 0.90820
# Epoch 38/500
# 788/788 [==============================] - 113s 143ms/step - loss: 2.2224 - acc: 0.9782 - IOU: 0.9496
#  - val_iou: 0.9094000000000001 - val_mse: 152.58960000000002
#
# Epoch 00038: val_iou improved from 0.90820 to 0.90940, saving model to mobilenetv2-flatten-0.91.h5
# Epoch 39/500
# 378/788 [=============>................] - ETA: 59s - loss: 2.0995 - acc: 0.9773 - IOU: 0.9517
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 547, img height 416)
#
# 788/788 [==============================] - 116s 147ms/step - loss: 2.1634 - acc: 0.9784 - IOU: 0.9506
#  - val_iou: 0.9063 - val_mse: 153.40030000000002
#
# Epoch 00039: val_iou did not improve from 0.90940
# Epoch 40/500
# 788/788 [==============================] - 114s 145ms/step - loss: 2.1273 - acc: 0.9796 - IOU: 0.9512
#  - val_iou: 0.9028 - val_mse: 153.7237
#
# Epoch 00040: val_iou did not improve from 0.90940
# Epoch 41/500
# 468/788 [================>.............] - ETA: 46s - loss: 2.0417 - acc: 0.9792 - IOU: 0.9526
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 617, img height 416)
#
# 788/788 [==============================] - 115s 145ms/step - loss: 2.0749 - acc: 0.9798 - IOU: 0.9524
#  - val_iou: 0.9045000000000001 - val_mse: 153.41930000000002
#
# Epoch 00041: val_iou did not improve from 0.90940
# Epoch 42/500
# 788/788 [==============================] - ETA: 0s - loss: 2.0598 - acc: 0.9801 - IOU: 0.952 - 114s 144ms/step - loss: 2.0599 - acc: 0.9800 - IOU: 0.9527
#  - val_iou: 0.9103 - val_mse: 153.42270000000002
#
# Epoch 00042: val_iou improved from 0.90940 to 0.91030, saving model to mobilenetv2-flatten-0.91.h5
# Epoch 43/500
# 788/788 [==============================] - 113s 143ms/step - loss: 2.0322 - acc: 0.9803 - IOU: 0.9530
#  - val_iou: 0.9089 - val_mse: 152.9186
#
# Epoch 00043: val_iou did not improve from 0.91030
# Epoch 44/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.9706 - acc: 0.9803 - IOU: 0.9546
#  - val_iou: 0.9075000000000001 - val_mse: 153.5111
#
# Epoch 00044: val_iou did not improve from 0.91030
# Epoch 45/500
# 788/788 [==============================] - 115s 145ms/step - loss: 1.9567 - acc: 0.9802 - IOU: 0.9547
#  - val_iou: 0.9074000000000001 - val_mse: 152.5421
#
# Epoch 00045: val_iou did not improve from 0.91030
# Epoch 46/500
#  11/788 [..............................] - ETA: 1:55 - loss: 1.6258 - acc: 0.9801 - IOU: 0.9622
# Warning: cropped too much (obj width 0.0, obj height -17.0, img width 580, img height 399)
#
# 385/788 [=============>................] - ETA: 58s - loss: 1.9255 - acc: 0.9796 - IOU: 0.9555
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 547, img height 416)
#
# 788/788 [==============================] - 114s 145ms/step - loss: 1.9369 - acc: 0.9811 - IOU: 0.9552
#  - val_iou: 0.9043 - val_mse: 153.0581
#
# Epoch 00046: val_iou did not improve from 0.91030
# Epoch 47/500
#  28/788 [>.............................] - ETA: 1:54 - loss: 1.9987 - acc: 0.9799 - IOU: 0.9546
# Warning: cropped too much (obj width 0.0, obj height -17.0, img width 580, img height 399)
#
# 788/788 [==============================] - 115s 146ms/step - loss: 1.9106 - acc: 0.9812 - IOU: 0.9556
#  - val_iou: 0.908 - val_mse: 152.06730000000002
#
# Epoch 00047: val_iou did not improve from 0.91030
# Epoch 48/500
# 374/788 [=============>................] - ETA: 1:00 - loss: 1.8777 - acc: 0.9802 - IOU: 0.9562
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 547, img height 416)
#
# 788/788 [==============================] - 115s 146ms/step - loss: 1.8990 - acc: 0.9805 - IOU: 0.9561
#  - val_iou: 0.9106000000000001 - val_mse: 153.7869
#
# Epoch 00048: val_iou improved from 0.91030 to 0.91060, saving model to mobilenetv2-flatten-0.91.h5
# Epoch 49/500
# 788/788 [==============================] - 113s 143ms/step - loss: 1.8800 - acc: 0.9795 - IOU: 0.9565
#  - val_iou: 0.9052 - val_mse: 153.6808
#
# Epoch 00049: val_iou did not improve from 0.91060
# Epoch 50/500
# 788/788 [==============================] - 116s 147ms/step - loss: 1.8489 - acc: 0.9810 - IOU: 0.9573
#  - val_iou: 0.904 - val_mse: 154.2218
#
# Epoch 00050: val_iou did not improve from 0.91060
# Epoch 51/500
# 788/788 [==============================] - 115s 146ms/step - loss: 1.8651 - acc: 0.9816 - IOU: 0.9571
#  - val_iou: 0.9089 - val_mse: 153.6078
#
# Epoch 00051: val_iou did not improve from 0.91060
# Epoch 52/500
# 379/788 [=============>................] - ETA: 1:00 - loss: 1.7970 - acc: 0.9839 - IOU: 0.9573
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 547, img height 416)
#
# 788/788 [==============================] - 115s 146ms/step - loss: 1.8428 - acc: 0.9821 - IOU: 0.9573
#  - val_iou: 0.9097000000000001 - val_mse: 152.7733
#
# Epoch 00052: val_iou did not improve from 0.91060
# Epoch 53/500
# 473/788 [=================>............] - ETA: 45s - loss: 1.8072 - acc: 0.9833 - IOU: 0.9574
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 617, img height 416)
#
# 788/788 [==============================] - 114s 145ms/step - loss: 1.8341 - acc: 0.9827 - IOU: 0.9575
#  - val_iou: 0.91 - val_mse: 154.58790000000002
#
# Epoch 00053: val_iou did not improve from 0.91060
# Epoch 54/500
# 788/788 [==============================] - 115s 145ms/step - loss: 1.8082 - acc: 0.9819 - IOU: 0.9583
#  - val_iou: 0.9091 - val_mse: 154.0138
#
# Epoch 00054: val_iou did not improve from 0.91060
# Epoch 55/500
# 788/788 [==============================] - 116s 148ms/step - loss: 1.7737 - acc: 0.9816 - IOU: 0.9589
#  - val_iou: 0.9099 - val_mse: 153.5016
#
# Epoch 00055: val_iou did not improve from 0.91060
# Epoch 56/500
# 421/788 [===============>..............] - ETA: 53s - loss: 1.7208 - acc: 0.9839 - IOU: 0.9598
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 519, img height 417)
#
# 788/788 [==============================] - 113s 144ms/step - loss: 1.7680 - acc: 0.9813 - IOU: 0.9592
#  - val_iou: 0.9105000000000001 - val_mse: 153.22660000000002
#
# Epoch 00056: val_iou did not improve from 0.91060
# Epoch 57/500
# 788/788 [==============================] - 115s 145ms/step - loss: 1.7556 - acc: 0.9825 - IOU: 0.9596
#  - val_iou: 0.907 - val_mse: 152.31640000000002
#
# Epoch 00057: val_iou did not improve from 0.91060
# Epoch 58/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.7545 - acc: 0.9822 - IOU: 0.9595
#  - val_iou: 0.9092 - val_mse: 153.4836
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 00058: val_iou did not improve from 0.91060
# Epoch 59/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.6364 - acc: 0.9824 - IOU: 0.9622
#  - val_iou: 0.9098 - val_mse: 153.12040000000002
#
# Epoch 00059: val_iou did not improve from 0.91060
# Epoch 60/500
# 788/788 [==============================] - 113s 144ms/step - loss: 1.6013 - acc: 0.9820 - IOU: 0.9631
#  - val_iou: 0.9102 - val_mse: 153.178
#
# Epoch 00060: val_iou did not improve from 0.91060
# Epoch 61/500
# 788/788 [==============================] - 113s 144ms/step - loss: 1.5674 - acc: 0.9826 - IOU: 0.9636
#  - val_iou: 0.9093 - val_mse: 153.16330000000002
#
# Epoch 00061: val_iou did not improve from 0.91060
# Epoch 62/500
# 788/788 [==============================] - 112s 143ms/step - loss: 1.5886 - acc: 0.9831 - IOU: 0.9634
#  - val_iou: 0.9097000000000001 - val_mse: 153.1686
#
# Epoch 00062: val_iou did not improve from 0.91060
# Epoch 63/500
# 496/788 [=================>............] - ETA: 42s - loss: 1.5627 - acc: 0.9848 - IOU: 0.9640
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 542, img height 369)
#
# 788/788 [==============================] - 114s 145ms/step - loss: 1.5674 - acc: 0.9837 - IOU: 0.9637
#  - val_iou: 0.9093 - val_mse: 153.7082
#
# Epoch 00063: val_iou did not improve from 0.91060
# Epoch 64/500
# 788/788 [==============================] - 115s 147ms/step - loss: 1.5615 - acc: 0.9835 - IOU: 0.9639
#  - val_iou: 0.911 - val_mse: 153.52530000000002
#
# Epoch 00064: val_iou improved from 0.91060 to 0.91100, saving model to mobilenetv2-flatten-0.91.h5
# Epoch 65/500
# 788/788 [==============================] - 113s 143ms/step - loss: 1.5524 - acc: 0.9826 - IOU: 0.9641
#  - val_iou: 0.9085000000000001 - val_mse: 153.244
#
# Epoch 00065: val_iou did not improve from 0.91100
# Epoch 66/500
# 788/788 [==============================] - 115s 146ms/step - loss: 1.5393 - acc: 0.9841 - IOU: 0.9643
#  - val_iou: 0.9103 - val_mse: 153.50660000000002
#
# Epoch 00066: val_iou did not improve from 0.91100
# Epoch 67/500
# 152/788 [====>.........................] - ETA: 1:30 - loss: 1.5307 - acc: 0.9807 - IOU: 0.9643
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 572, img height 426)
#
# 788/788 [==============================] - 112s 142ms/step - loss: 1.5436 - acc: 0.9830 - IOU: 0.9641
#  - val_iou: 0.9087000000000001 - val_mse: 153.6046
#
# Epoch 00067: val_iou did not improve from 0.91100
# Epoch 68/500
# 456/788 [================>.............] - ETA: 47s - loss: 1.5556 - acc: 0.9833 - IOU: 0.9642
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 617, img height 416)
#
# 788/788 [==============================] - 114s 145ms/step - loss: 1.5467 - acc: 0.9842 - IOU: 0.9643
#  - val_iou: 0.9089 - val_mse: 153.559
#
# Epoch 00068: val_iou did not improve from 0.91100
# Epoch 69/500
# 788/788 [==============================] - 113s 144ms/step - loss: 1.5182 - acc: 0.9831 - IOU: 0.9648
#  - val_iou: 0.9096000000000001 - val_mse: 153.74960000000002
#
# Epoch 00069: val_iou did not improve from 0.91100
# Epoch 70/500
# 788/788 [==============================] - 113s 143ms/step - loss: 1.5235 - acc: 0.9843 - IOU: 0.9649
#  - val_iou: 0.9103 - val_mse: 153.3463
#
# Epoch 00070: val_iou did not improve from 0.91100
# Epoch 71/500
# 788/788 [==============================] - 115s 146ms/step - loss: 1.5200 - acc: 0.9841 - IOU: 0.9649
#  - val_iou: 0.9066000000000001 - val_mse: 153.2774
#
# Epoch 00071: val_iou did not improve from 0.91100
# Epoch 72/500
# 184/788 [======>.......................] - ETA: 1:26 - loss: 1.4174 - acc: 0.9869 - IOU: 0.9658
# Warning: cropped too much (obj width 0.0, obj height -44.0, img width 521, img height 390)
# 185/788 [======>.......................] - ETA: 1:26 - loss: 1.4158 - acc: 0.9870 - IOU: 0.9658
# 788/788 [==============================] - 113s 143ms/step - loss: 1.5111 - acc: 0.9842 - IOU: 0.9652
#  - val_iou: 0.9104000000000001 - val_mse: 153.61690000000002
#
# Epoch 00072: val_iou did not improve from 0.91100
# Epoch 73/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.5217 - acc: 0.9840 - IOU: 0.9649
#  - val_iou: 0.9095000000000001 - val_mse: 153.7053
#
# Epoch 00073: val_iou did not improve from 0.91100
# Epoch 74/500
# 382/788 [=============>................] - ETA: 58s - loss: 1.5385 - acc: 0.9836 - IOU: 0.9645
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 547, img height 416)
#
# 788/788 [==============================] - 113s 144ms/step - loss: 1.5115 - acc: 0.9847 - IOU: 0.9650
#  - val_iou: 0.9095000000000001 - val_mse: 153.5075
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 00074: val_iou did not improve from 0.91100
# Epoch 75/500
# 658/788 [========================>.....] - ETA: 18s - loss: 1.4810 - acc: 0.9837 - IOU: 0.9656
# Warning: cropped too much (obj width 0.0, obj height -9.0, img width 567, img height 391)
#
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4671 - acc: 0.9841 - IOU: 0.9661
#  - val_iou: 0.9097000000000001 - val_mse: 153.42950000000002
#
# Epoch 00075: val_iou did not improve from 0.91100
# Epoch 76/500
# 788/788 [==============================] - 113s 143ms/step - loss: 1.4692 - acc: 0.9841 - IOU: 0.9661
#  - val_iou: 0.9099 - val_mse: 153.26520000000002
#
# Epoch 00076: val_iou did not improve from 0.91100
# Epoch 77/500
# 236/788 [=======>......................] - ETA: 1:21 - loss: 1.3974 - acc: 0.9813 - IOU: 0.9662
# Warning: cropped too much (obj width 0.0, obj height -54.0, img width 551, img height 372)
#
# 788/788 [==============================] - 115s 146ms/step - loss: 1.4754 - acc: 0.9850 - IOU: 0.9658
#  - val_iou: 0.9098 - val_mse: 153.3526
#
# Epoch 00077: val_iou did not improve from 0.91100
# Epoch 78/500
# 788/788 [==============================] - 113s 144ms/step - loss: 1.4629 - acc: 0.9852 - IOU: 0.9660
#  - val_iou: 0.9096000000000001 - val_mse: 153.4215
#
# Epoch 00078: val_iou did not improve from 0.91100
# Epoch 79/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4682 - acc: 0.9842 - IOU: 0.9663
#  - val_iou: 0.91 - val_mse: 153.5034
#
# Epoch 00079: val_iou did not improve from 0.91100
# Epoch 80/500
# 788/788 [==============================] - 113s 144ms/step - loss: 1.4526 - acc: 0.9848 - IOU: 0.9664
#  - val_iou: 0.9099 - val_mse: 153.6141
#
# Epoch 00080: val_iou did not improve from 0.91100
# Epoch 81/500
#  19/788 [..............................] - ETA: 2:01 - loss: 1.2056 - acc: 0.9852 - IOU: 0.9688
# Warning: cropped too much (obj width 0.0, obj height -17.0, img width 580, img height 399)
#
# 788/788 [==============================] - 113s 143ms/step - loss: 1.4696 - acc: 0.9838 - IOU: 0.9661
#  - val_iou: 0.9095000000000001 - val_mse: 153.6317
#
# Epoch 00081: val_iou did not improve from 0.91100
# Epoch 82/500
# 788/788 [==============================] - 116s 147ms/step - loss: 1.4801 - acc: 0.9830 - IOU: 0.9659
#  - val_iou: 0.9103 - val_mse: 153.631
#
# Epoch 00082: val_iou did not improve from 0.91100
# Epoch 83/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4416 - acc: 0.9850 - IOU: 0.9666
#  - val_iou: 0.9093 - val_mse: 153.4554
#
# Epoch 00083: val_iou did not improve from 0.91100
# Epoch 84/500
# 788/788 [==============================] - 116s 147ms/step - loss: 1.4717 - acc: 0.9855 - IOU: 0.9660
#  - val_iou: 0.9095000000000001 - val_mse: 153.335
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 00084: val_iou did not improve from 0.91100
# Epoch 85/500
# 788/788 [==============================] - 113s 143ms/step - loss: 1.4593 - acc: 0.9843 - IOU: 0.9663
#  - val_iou: 0.9096000000000001 - val_mse: 153.4049
#
# Epoch 00085: val_iou did not improve from 0.91100
# Epoch 86/500
#  29/788 [>.............................] - ETA: 1:49 - loss: 1.2611 - acc: 0.9860 - IOU: 0.9693
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 512, img height 405)
#
# 788/788 [==============================] - 113s 143ms/step - loss: 1.4580 - acc: 0.9850 - IOU: 0.9664
#  - val_iou: 0.9098 - val_mse: 153.4219
#
# Epoch 00086: val_iou did not improve from 0.91100
# Epoch 87/500
#  90/788 [==>...........................] - ETA: 1:40 - loss: 1.3496 - acc: 0.9809 - IOU: 0.9682
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 537, img height 424)
#  91/788 [==>...........................] - ETA: 1:40 - loss: 1.3470 - acc: 0.9808 - IOU: 0.9682
# 788/788 [==============================] - 113s 144ms/step - loss: 1.4659 - acc: 0.9844 - IOU: 0.9661
#  - val_iou: 0.9101 - val_mse: 153.466
#
# Epoch 00087: val_iou did not improve from 0.91100
# Epoch 88/500
# 457/788 [================>.............] - ETA: 47s - loss: 1.4585 - acc: 0.9839 - IOU: 0.9665
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 617, img height 416)
#
# 788/788 [==============================] - 113s 143ms/step - loss: 1.4531 - acc: 0.9848 - IOU: 0.9663
#  - val_iou: 0.9098 - val_mse: 153.4504
#
# Epoch 00088: val_iou did not improve from 0.91100
# Epoch 89/500
# 788/788 [==============================] - 113s 144ms/step - loss: 1.4501 - acc: 0.9848 - IOU: 0.9665
#  - val_iou: 0.9099 - val_mse: 153.4442
#
# Epoch 00089: val_iou did not improve from 0.91100
# Epoch 90/500
# 788/788 [==============================] - 113s 144ms/step - loss: 1.4651 - acc: 0.9847 - IOU: 0.9663
#  - val_iou: 0.9097000000000001 - val_mse: 153.43970000000002
#
# Epoch 00090: val_iou did not improve from 0.91100
# Epoch 91/500
# 788/788 [==============================] - 113s 144ms/step - loss: 1.4313 - acc: 0.9849 - IOU: 0.9668
#  - val_iou: 0.9098 - val_mse: 153.4378
#
# Epoch 00091: val_iou did not improve from 0.91100
# Epoch 92/500
# 788/788 [==============================] - 113s 143ms/step - loss: 1.4415 - acc: 0.9850 - IOU: 0.9667
#  - val_iou: 0.91 - val_mse: 153.4468
#
# Epoch 00092: val_iou did not improve from 0.91100
# Epoch 93/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4553 - acc: 0.9849 - IOU: 0.9663
#  - val_iou: 0.9098 - val_mse: 153.4187
#
# Epoch 00093: val_iou did not improve from 0.91100
# Epoch 94/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4548 - acc: 0.9846 - IOU: 0.9667
#  - val_iou: 0.9102 - val_mse: 153.45780000000002
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
#
# Epoch 00094: val_iou did not improve from 0.91100
# Epoch 95/500
# 788/788 [==============================] - 114s 144ms/step - loss: 1.4405 - acc: 0.9850 - IOU: 0.9668
#  - val_iou: 0.9101 - val_mse: 153.4556
#
# Epoch 00095: val_iou did not improve from 0.91100
# Epoch 96/500
# 788/788 [==============================] - 112s 143ms/step - loss: 1.4511 - acc: 0.9856 - IOU: 0.9664
#  - val_iou: 0.91 - val_mse: 153.4727
#
# Epoch 00096: val_iou did not improve from 0.91100
# Epoch 97/500
# 414/788 [==============>...............] - ETA: 53s - loss: 1.4961 - acc: 0.9842 - IOU: 0.9653
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 519, img height 417)
#
# 788/788 [==============================] - 113s 144ms/step - loss: 1.4582 - acc: 0.9849 - IOU: 0.9661
#  - val_iou: 0.9101 - val_mse: 153.4496
#
# Epoch 00097: val_iou did not improve from 0.91100
# Epoch 98/500
# 788/788 [==============================] - 116s 147ms/step - loss: 1.4415 - acc: 0.9845 - IOU: 0.9667
#  - val_iou: 0.91 - val_mse: 153.4292
#
# Epoch 00098: val_iou did not improve from 0.91100
# Epoch 99/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4495 - acc: 0.9849 - IOU: 0.9666
#  - val_iou: 0.9101 - val_mse: 153.4459
#
# Epoch 00099: val_iou did not improve from 0.91100
# Epoch 100/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4632 - acc: 0.9847 - IOU: 0.9663
#  - val_iou: 0.91 - val_mse: 153.43200000000002
#
# Epoch 00100: val_iou did not improve from 0.91100
# Epoch 101/500
# 788/788 [==============================] - 115s 146ms/step - loss: 1.4471 - acc: 0.9837 - IOU: 0.9666
#  - val_iou: 0.91 - val_mse: 153.4498
#
# Epoch 00101: val_iou did not improve from 0.91100
# Epoch 102/500
# 788/788 [==============================] - 116s 147ms/step - loss: 1.4421 - acc: 0.9853 - IOU: 0.9666
#  - val_iou: 0.91 - val_mse: 153.4451
#
# Epoch 00102: val_iou did not improve from 0.91100
# Epoch 103/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4625 - acc: 0.9849 - IOU: 0.9664
#  - val_iou: 0.91 - val_mse: 153.447
#
# Epoch 00103: val_iou did not improve from 0.91100
# Epoch 104/500
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4598 - acc: 0.9843 - IOU: 0.9664
#  - val_iou: 0.91 - val_mse: 153.45270000000002
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 00104: val_iou did not improve from 0.91100
# Epoch 105/500
# 181/788 [=====>........................] - ETA: 1:28 - loss: 1.3422 - acc: 0.9834 - IOU: 0.9672
# Warning: cropped too much (obj width 0.0, obj height -44.0, img width 521, img height 390)
# 182/788 [=====>........................] - ETA: 1:28 - loss: 1.3407 - acc: 0.9835 - IOU: 0.9672
# 456/788 [================>.............] - ETA: 47s - loss: 1.4735 - acc: 0.9848 - IOU: 0.9658
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 617, img height 416)
#
# 788/788 [==============================] - 115s 145ms/step - loss: 1.4460 - acc: 0.9840 - IOU: 0.9667
#  - val_iou: 0.91 - val_mse: 153.45510000000002
#
# Epoch 00105: val_iou did not improve from 0.91100
# Epoch 106/500
# 788/788 [==============================] - 115s 146ms/step - loss: 1.4493 - acc: 0.9852 - IOU: 0.9665
#  - val_iou: 0.91 - val_mse: 153.4576
#
# Epoch 00106: val_iou did not improve from 0.91100
# Epoch 107/500
#  11/788 [..............................] - ETA: 1:57 - loss: 1.1964 - acc: 0.9830 - IOU: 0.9680
# Warning: cropped too much (obj width 0.0, obj height -17.0, img width 580, img height 399)
#
# 788/788 [==============================] - 114s 145ms/step - loss: 1.4415 - acc: 0.9843 - IOU: 0.9666
#  - val_iou: 0.9101 - val_mse: 153.4684
#
# Epoch 00107: val_iou did not improve from 0.91100
# Epoch 108/500
# 655/788 [=======================>......] - ETA: 19s - loss: 1.4721 - acc: 0.9839 - IOU: 0.9659
# Warning: cropped too much (obj width 0.0, obj height -9.0, img width 567, img height 391)
#
# 788/788 [==============================] - 114s 144ms/step - loss: 1.4676 - acc: 0.9844 - IOU: 0.9662
#  - val_iou: 0.9101 - val_mse: 153.4874
#
# Epoch 00108: val_iou did not improve from 0.91100
# Epoch 109/500
# 788/788 [==============================] - 113s 144ms/step - loss: 1.4343 - acc: 0.9849 - IOU: 0.9668
#  - val_iou: 0.9101 - val_mse: 153.4519
#
# Epoch 00109: val_iou did not improve from 0.91100
# Epoch 110/500
# 788/788 [==============================] - 113s 143ms/step - loss: 1.4494 - acc: 0.9839 - IOU: 0.9665
#  - val_iou: 0.91 - val_mse: 153.4547
#
# Epoch 00110: val_iou did not improve from 0.91100
# Epoch 111/500
# 788/788 [==============================] - 115s 146ms/step - loss: 1.4431 - acc: 0.9852 - IOU: 0.9668
#  - val_iou: 0.9101 - val_mse: 153.45180000000002
#
# Epoch 00111: val_iou did not improve from 0.91100
# Epoch 112/500
# 788/788 [==============================] - 114s 144ms/step - loss: 1.4373 - acc: 0.9849 - IOU: 0.9666
#  - val_iou: 0.9101 - val_mse: 153.4562
#
# Epoch 00112: val_iou did not improve from 0.91100
# Epoch 113/500
#  34/788 [>.............................] - ETA: 1:50 - loss: 1.5190 - acc: 0.9862 - IOU: 0.9660
# Warning: cropped too much (obj width 0.0, obj height 0.0, img width 512, img height 405)
# 788/788 [==============================] - 113s 143ms/step - loss: 1.4632 - acc: 0.9839 - IOU: 0.9663
#  - val_iou: 0.91 - val_mse: 153.446
#
# Epoch 00113: val_iou did not improve from 0.91100
# Epoch 114/500
# 788/788 [==============================] - 115s 146ms/step - loss: 1.4423 - acc: 0.9847 - IOU: 0.9669
#  - val_iou: 0.9101 - val_mse: 153.4411
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 00114: val_iou did not improve from 0.91100

# %%
sample = pd.read_csv("train.csv")
sample.head()

# %%
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt

from keras.applications.mobilenetv2 import preprocess_input

WEIGHTS_FILE = "densenet_no_wts-data_aug-0.91.h5"
IMAGES = "images/*png"

# model = create_model()
model.load_weights(WEIGHTS_FILE)

# %%
for filename in glob.glob(IMAGES)[8000:8010]:
    unscaled = cv2.imread(filename)
    image_height, image_width, _ = unscaled.shape

    image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE))
    feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

    region = model.predict(x=np.array([feat_scaled]))[0]

    x0 = int(region[0] * image_width / IMAGE_SIZE)
    y0 = int(region[1] * image_height / IMAGE_SIZE)

    x1 = int((region[0] + region[2]) * image_width / IMAGE_SIZE)
    y1 = int((region[1] + region[3]) * image_height / IMAGE_SIZE)

    cv2.rectangle(unscaled, (x0, y0), (x1, y1), (0, 255, 0), 2)
    plt.imshow(unscaled)
    plt.show()

# %%
sample = pd.read_csv("validation.csv")
sample.head()

# %%
for index, row in sample.iterrows():
    unscaled = cv2.imread('images/'+row['image_name'])
    image_height, image_width, _ = unscaled.shape

    image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE))
    feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

    region = model.predict(x=np.array([feat_scaled]))[0]

    x1 = int(region[0] * image_width / IMAGE_SIZE)
    y1 = int(region[1] * image_height / IMAGE_SIZE)

    x2 = int((region[0] + region[2]) * image_width / IMAGE_SIZE)
    y2 = int((region[1] + region[3]) * image_height / IMAGE_SIZE)

    sample.iloc[index,1] = x1
    sample.iloc[index,2] = x2
    sample.iloc[index,3] = y1
    sample.iloc[index,4] = y2

sample.head()

# %%
sample.to_csv('valid_pred_densenet121.csv', index=False)
