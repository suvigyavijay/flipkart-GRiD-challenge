# %% [markdown]
# ### 1.3 ResNeXt50

# %% [markdown]
# DenseNet is almost a similar model to MobileNetV2 with comparable depth, but more parameters and size.

# %% [markdown]
# ### Imports

# %%
import math
from keras import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from keras.layers import *
from keras.utils import Sequence
from keras.backend import epsilon
import keras.backend as K
from keras.optimizers import Adam
from keras.regularizers import l2
import numpy as np
import pandas as pd
import os
from PIL import Image, ImageDraw, ImageEnhance
import cv2

IMAGE_SIZE = 224

EPOCHS = 500
BATCH_SIZE = 32
PATIENCE = 50

MULTI_PROCESSING = True
THREADS = 16
DATA_DIR = 'images/'

TRAIN_CSV = "train.csv"
VALIDATION_CSV = "validation.csv"
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Data Generators

# %%
class DataGenerator(Sequence):

    def __init__(self, csv_file,rnd_rescale=True, rnd_multiply=True, rnd_color=True, rnd_crop=True, rnd_flip=True,
                 batch_size = BATCH_SIZE, rnd_dice=True):
        self.paths = []
        self.coords = []
        self.batch_size = batch_size
        self.rnd_rescale = rnd_rescale
        self.rnd_multiply = rnd_multiply
        self.rnd_color = rnd_color
        self.rnd_crop = rnd_crop
        self.rnd_flip = rnd_flip
        self.rnd_dice = rnd_dice

        with open(csv_file, "r") as file:
            self.coords = np.zeros((sum(1 for line in file)-1, 4))
            
        df = pd.read_csv(csv_file)

        for index, row in df.iterrows():
            path = os.path.join(DATA_DIR, row['image_name'])
            x1 = row['x1']
            x2 = row['x2']
            y1 = row['y1']
            y2 = row['y2']

            img = Image.open(path)
            width, height = img.size

            self.coords[index, 0] = x1
            self.coords[index, 1] = y1
            self.coords[index, 2] = x2 
            self.coords[index, 3] = y2 

            self.paths.append(path)
        
    def __len__(self):
        return math.ceil(len(self.coords)*2 / self.batch_size)

    def __getitem__(self, idx):
        batch_paths = self.paths[idx * self.batch_size//2:(idx + 1) * self.batch_size//2]
        coords = self.coords[idx * self.batch_size//2:(idx + 1) * self.batch_size//2].copy()
        batch_coords = np.zeros((self.batch_size,4))
        batch_images = np.zeros((self.batch_size, IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
        i = 0
        for j, f in enumerate(batch_paths):
            img = Image.open(f)
            x0,y0,x1,y1 = coords[j]
            image_width = img.width
            image_height = img.height
            img2 = img.resize((IMAGE_SIZE, IMAGE_SIZE))
            img2 = img2.convert('RGB')
            img2 = np.array(img2, dtype=np.float32)
            batch_images[i] = preprocess_input(img2.copy())
            
            batch_coords[i, 0] = x0 * IMAGE_SIZE / image_width
            batch_coords[i, 1] = y0 * IMAGE_SIZE / image_height
            batch_coords[i, 2] = (x1 - x0) * IMAGE_SIZE / image_width
            batch_coords[i, 3] = (y1 - y0) * IMAGE_SIZE / image_height 
            
            if self.rnd_dice:
                
#                 select = np.random.randint(5)
                
                if self.rnd_rescale:
                    old_width = img.width
                    old_height = img.height

                    rescale = np.random.uniform(low=0.6, high=1.4)
                    new_width = int(old_width * rescale)
                    new_height = int(old_height * rescale)

                    img = img.resize((new_width, new_height))

                    x0 *= new_width / old_width
                    y0 *= new_height / old_height
                    x1 *= new_width / old_width
                    y1 *= new_height / old_height

                if self.rnd_crop:
                    start_x = np.random.randint(0, high=np.floor(0.15 * img.width))
                    stop_x = img.width - np.random.randint(0, high=np.floor(0.15 * img.width))
                    start_y = np.random.randint(0, high=np.floor(0.15 * img.height))
                    stop_y = img.height - np.random.randint(0, high=np.floor(0.15 * img.height))

                    img_temp = img.copy()
                    img = img.crop((start_x, start_y, stop_x, stop_y))
                    
                    x0_temp = x0
                    x1_temp = x1
                    y0_temp = y0
                    y1_temp = y1

                    x0 = max(x0 - start_x, 0)
                    y0 = max(y0 - start_y, 0)
                    x1 = min(x1 - start_x, img.width)
                    y1 = min(y1 - start_y, img.height)

                    if np.abs(x1 - x0) < 40 or np.abs(y1 - y0) < 40:
                        img = img_temp
                        x0 = x0_temp
                        x1 = x1_temp
                        y0 = y0_temp
                        y1 = y1_temp
#                         print("\nWarning: cropped too much (obj width {}, obj height {}, img width {}, img height {})\n".format(x1 - x0, y1 - y0, img.width, img.height))

                if self.rnd_flip:
                    elem = np.random.choice([0, 90, 180, 270, 1423, 1234])
                    if elem % 10 == 0:
                        x = x0 - img.width / 2
                        y = y0 - img.height / 2

                        x0 = img.width / 2 + x * np.cos(np.deg2rad(elem)) - y * np.sin(np.deg2rad(elem))
                        y0 = img.height / 2 + x * np.sin(np.deg2rad(elem)) + y * np.cos(np.deg2rad(elem))

                        x = x1 - img.width / 2
                        y = y1 - img.height / 2

                        x1 = img.width / 2 + x * np.cos(np.deg2rad(elem)) - y * np.sin(np.deg2rad(elem))
                        y1 = img.height / 2 + x * np.sin(np.deg2rad(elem)) + y * np.cos(np.deg2rad(elem))

                        img = img.rotate(-elem)
                    else:
                        if elem == 1423:
                            img = img.transpose(Image.FLIP_TOP_BOTTOM)
                            y0 = img.height - y0
                            y1 = img.height - y1

                        elif elem == 1234:
                            img = img.transpose(Image.FLIP_LEFT_RIGHT)
                            x0 = img.width - x0
                            x1 = img.width - x1

                image_width = img.width
                image_height = img.height

                tmp = x0
                x0 = min(x0, x1)
                x1 = max(tmp, x1)

                tmp = y0
                y0 = min(y0, y1)
                y1 = max(tmp, y1)

                x0 = max(x0, 0)
                y0 = max(y0, 0)

                y0 = min(y0, image_height)
                x0 = min(x0, image_width)
                y1 = min(y1, image_height)
                x1 = min(x1, image_width)

                if self.rnd_color:
                    enhancer = ImageEnhance.Color(img)
                    img = enhancer.enhance(np.random.uniform(low=0.5, high=1.5))

                    enhancer2 = ImageEnhance.Brightness(img)
                    img = enhancer.enhance(np.random.uniform(low=0.7, high=1.3))

                img = img.resize((IMAGE_SIZE, IMAGE_SIZE))
                img = img.convert('RGB')
                pil_img = img
                img = np.array(img, dtype=np.float32)
                pil_img.close()
                
                if self.rnd_multiply:
                    img[...,0] = np.floor(np.clip(img[...,0] * np.random.uniform(low=0.8, high=1.2), 0.0, 255.0))
                    img[...,1] = np.floor(np.clip(img[...,1] * np.random.uniform(low=0.8, high=1.2), 0.0, 255.0))
                    img[...,2] = np.floor(np.clip(img[...,2] * np.random.uniform(low=0.8, high=1.2), 0.0, 255.0))

                batch_images[i+1] = preprocess_input(img.copy())

                batch_coords[i+1, 0] = x0 * IMAGE_SIZE / image_width
                batch_coords[i+1, 1] = y0 * IMAGE_SIZE / image_height
                batch_coords[i+1, 2] = (x1 - x0) * IMAGE_SIZE / image_width
                batch_coords[i+1, 3] = (y1 - y0) * IMAGE_SIZE / image_height 
                
            i+=2
            
        return batch_images, batch_coords

# %% [markdown]
# ### Loss Function

# %%
import tensorflow as tf

def IOU(y_true, y_pred):
    diff_width = K.minimum(y_true[:,0] + y_true[:,2], y_pred[:,0] + y_pred[:,2]) - K.maximum(y_true[:,0], y_pred[:,0])
    diff_height = K.minimum(y_true[:,1] + y_true[:,3], y_pred[:,1] + y_pred[:,3]) - K.maximum(y_true[:,1], y_pred[:,1])
    intersection = K.maximum(diff_width, 0) * K.maximum(diff_height, 0)

    area_gt = y_true[:,2] * y_true[:,3]
    area_pred = y_pred[:,2] * y_pred[:,3]
    union = K.maximum(area_gt + area_pred - intersection, 0)

    #ntersection = K.sum(intersection * (union > 0))
    intersection = tf.where(union > 0, intersection, K.zeros_like(intersection))
    intersection = K.sum(intersection)
    union = K.sum(union)
    iou = (intersection / (union + epsilon()))
    return iou

# %% [markdown]
# ### Loading Validation Data into the Memory

# %% [markdown]
# Unlike training data validation can still be performed via loading data into memory, and will help improve training time. Also, as we are not doing any augmentation in the validation data we can save some time by defining another data generator just for validation purpose.

# %%
from keras.applications.resnext import preprocess_input

valData = pd.read_csv('validation.csv')

val_coords = np.zeros((len(valData),4))
val_images = np.zeros((len(valData), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)

for index, row in valData.iterrows():
    path = os.path.join(DATA_DIR, row['image_name'])
    x1 = row['x1']
    x2 = row['x2']
    y1 = row['y1']
    y2 = row['y2']

    img = Image.open(path)
    width, height = img.size

    val_coords[index, 0] = x1*IMAGE_SIZE / width
    val_coords[index, 1] = y1*IMAGE_SIZE / height
    val_coords[index, 2] = (x2 - x1)* IMAGE_SIZE / width
    val_coords[index, 3] = (y2 - y1)*IMAGE_SIZE / height 
    
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE))
    img = img.convert('RGB')
    pil_img = img
    img = np.array(img, dtype=np.float32)
    val_images[index] = preprocess_input(img.copy())
    pil_img.close()

class ValDataGenerator(Sequence):
    def __init__(self, val_images, val_coords, batch_size = BATCH_SIZE):
        self.images = val_images
        self.coords = val_coords
        self.batch_size = batch_size
        
    def __len__(self):
        return math.ceil(len(self.coords) / self.batch_size)
    
    def __getitem__(self, idx):
        batch_coords = self.coords[idx * self.batch_size:(idx + 1) * self.batch_size].copy()
        batch_images = self.images[idx * self.batch_size:(idx + 1) * self.batch_size]
        return batch_images, batch_coords

# %% [markdown]
# Let's go ahead and define our model, having base model as DenseNet121.

# %%
from keras.applications.resnext import ResNeXt50

def resnext_model(trainable=True):
    model = ResNeXt50(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False, weights='imagenet')

    for layer in model.layers:
        layer.trainable = trainable

    x = model.layers[-1].output
    x = Conv2D(256, kernel_size=3, name="mn1", activation='relu')(x)
    x = Conv2D(4, kernel_size=5, name="mn2", activation='relu')(x)
    x = Reshape((4,))(x)

    return Model(inputs=model.input, outputs=x)

# %% [markdown]
# **Note: We have set `weights=None` because of the competition requirements of "no transfer learning" on the discussion board, but setting `weights='imagenet'` improves the prediction as well as the training time.**
#
#
# Currently, weights are initialized randomly and thus takes a lot more time to train than starting off with imagenet weights.

# %%
resnx = resnext_model()
resnx.summary()
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnext50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 92659712/92652672 [==============================] - 3s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9408        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 128)  8192        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 58, 58, 128)  0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (DepthwiseC (None, 56, 56, 512)  4608        conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 56, 56, 32, 4 0           conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_reduce (Lambda)  (None, 56, 56, 32, 4 0           reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 56, 56, 128)  0           conv2_block1_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 128)  512         reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 128)  0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16384       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  32768       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 128)  32768       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 58, 58, 128)  0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (DepthwiseC (None, 56, 56, 512)  4608        conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 56, 56, 32, 4 0           conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_reduce (Lambda)  (None, 56, 56, 32, 4 0           reshape_3[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 56, 56, 128)  0           conv2_block2_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 128)  512         reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 128)  0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  32768       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 128)  32768       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 58, 58, 128)  0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (DepthwiseC (None, 56, 56, 512)  4608        conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 56, 56, 32, 4 0           conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_reduce (Lambda)  (None, 56, 56, 32, 4 0           reshape_5[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 56, 56, 128)  0           conv2_block3_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 128)  512         reshape_6[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 128)  0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  32768       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 56, 56, 256)  65536       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 56, 56, 256)  1024        conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 56, 56, 256)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 58, 58, 256)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (DepthwiseC (None, 28, 28, 2048) 18432       conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 28, 28, 32, 8 0           conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_reduce (Lambda)  (None, 28, 28, 32, 8 0           reshape_7[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 28, 28, 256)  0           conv3_block1_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 256)  1024        reshape_8[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 256)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131072      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  131072      conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 256)  131072      conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 256)  1024        conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 256)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 30, 30, 256)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (DepthwiseC (None, 28, 28, 2048) 18432       conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 28, 28, 32, 8 0           conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_reduce (Lambda)  (None, 28, 28, 32, 8 0           reshape_9[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 28, 28, 256)  0           conv3_block2_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 256)  1024        reshape_10[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 256)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  131072      conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 256)  131072      conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 256)  1024        conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 256)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 30, 30, 256)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (DepthwiseC (None, 28, 28, 2048) 18432       conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 28, 28, 32, 8 0           conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_reduce (Lambda)  (None, 28, 28, 32, 8 0           reshape_11[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 28, 28, 256)  0           conv3_block3_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 256)  1024        reshape_12[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 256)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  131072      conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 256)  131072      conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 256)  1024        conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 256)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 30, 30, 256)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (DepthwiseC (None, 28, 28, 2048) 18432       conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 28, 28, 32, 8 0           conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_reduce (Lambda)  (None, 28, 28, 32, 8 0           reshape_13[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 28, 28, 256)  0           conv3_block4_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 256)  1024        reshape_14[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 256)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  131072      conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 28, 28, 512)  262144      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 28, 28, 512)  2048        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 28, 28, 512)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 30, 30, 512)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (DepthwiseC (None, 14, 14, 8192) 73728       conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 14, 14, 32, 1 0           conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_reduce (Lambda)  (None, 14, 14, 32, 1 0           reshape_15[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 14, 14, 512)  0           conv4_block1_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 512)  2048        reshape_16[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 512)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 524288      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 524288      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 512)  524288      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 512)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 16, 16, 512)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (DepthwiseC (None, 14, 14, 8192) 73728       conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 14, 14, 32, 1 0           conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_reduce (Lambda)  (None, 14, 14, 32, 1 0           reshape_17[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 14, 14, 512)  0           conv4_block2_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 512)  2048        reshape_18[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 512)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 524288      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 512)  524288      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 512)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 16, 16, 512)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (DepthwiseC (None, 14, 14, 8192) 73728       conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 14, 14, 32, 1 0           conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_reduce (Lambda)  (None, 14, 14, 32, 1 0           reshape_19[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 14, 14, 512)  0           conv4_block3_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 512)  2048        reshape_20[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 512)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 524288      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 512)  524288      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 512)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 16, 16, 512)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (DepthwiseC (None, 14, 14, 8192) 73728       conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 14, 14, 32, 1 0           conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_reduce (Lambda)  (None, 14, 14, 32, 1 0           reshape_21[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 14, 14, 512)  0           conv4_block4_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 512)  2048        reshape_22[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 512)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 524288      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 512)  524288      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 512)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 16, 16, 512)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (DepthwiseC (None, 14, 14, 8192) 73728       conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 14, 14, 32, 1 0           conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_reduce (Lambda)  (None, 14, 14, 32, 1 0           reshape_23[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 14, 14, 512)  0           conv4_block5_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 512)  2048        reshape_24[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 512)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 524288      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 512)  524288      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 512)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 16, 16, 512)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (DepthwiseC (None, 14, 14, 8192) 73728       conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 14, 14, 32, 1 0           conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_reduce (Lambda)  (None, 14, 14, 32, 1 0           reshape_25[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 14, 14, 512)  0           conv4_block6_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 512)  2048        reshape_26[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 512)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 524288      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 14, 14, 1024) 1048576     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 14, 14, 1024) 4096        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 14, 14, 1024) 0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 16, 16, 1024) 0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (DepthwiseC (None, 7, 7, 32768)  294912      conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_27 (Reshape)            (None, 7, 7, 32, 32, 0           conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_reduce (Lambda)  (None, 7, 7, 32, 32) 0           reshape_27[0][0]
# __________________________________________________________________________________________________
# reshape_28 (Reshape)            (None, 7, 7, 1024)   0           conv5_block1_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 1024)   4096        reshape_28[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 1024)   0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2097152     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   2097152     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 1024)   2097152     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 1024)   4096        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 1024)   0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 9, 9, 1024)   0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (DepthwiseC (None, 7, 7, 32768)  294912      conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_29 (Reshape)            (None, 7, 7, 32, 32, 0           conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_reduce (Lambda)  (None, 7, 7, 32, 32) 0           reshape_29[0][0]
# __________________________________________________________________________________________________
# reshape_30 (Reshape)            (None, 7, 7, 1024)   0           conv5_block2_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 1024)   4096        reshape_30[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 1024)   0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   2097152     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 1024)   2097152     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 1024)   4096        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 1024)   0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 9, 9, 1024)   0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (DepthwiseC (None, 7, 7, 32768)  294912      conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# reshape_31 (Reshape)            (None, 7, 7, 32, 32, 0           conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_reduce (Lambda)  (None, 7, 7, 32, 32) 0           reshape_31[0][0]
# __________________________________________________________________________________________________
# reshape_32 (Reshape)            (None, 7, 7, 1024)   0           conv5_block3_2_reduce[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 1024)   4096        reshape_32[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 1024)   0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   2097152     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# mn1 (Conv2D)                    (None, 5, 5, 256)    4718848     conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# mn2 (Conv2D)                    (None, 1, 1, 4)      25604       mn1[0][0]
# __________________________________________________________________________________________________
# reshape_33 (Reshape)            (None, 4)            0           mn2[0][0]
# ==================================================================================================
# Total params: 27,792,580
# Trainable params: 27,724,356
# Non-trainable params: 68,224
# __________________________________________________________________________________________________

# %% [markdown]
# Now that we have defined the model, let's compile it and intialize other variables for training including checkpoint, early stopping and scheduling learning rate.

# %%
resnx.compile(loss="mean_absolute_error", optimizer="adam", metrics=['accuracy',IOU])

checkpoint = ModelCheckpoint("resnext-{val_IOU:.2f}.h5", monitor="val_IOU", verbose=1, save_best_only=True, save_weights_only=True, mode="max", period=1)

stop = EarlyStopping(monitor="val_IOU", patience=PATIENCE, mode="max")

reduce_lr = ReduceLROnPlateau(monitor="val_IOU", factor=0.2, patience=5, min_lr=1e-7, verbose=1, mode="max")

# %% [markdown]
# Now, let's finally intialize our data generators and train the model.

# %%
train_datagen = DataGenerator(TRAIN_CSV)
validation_datagen = ValDataGenerator(val_images, val_coords)

# %%
resnx.fit_generator(generator=train_datagen,
                    validation_data=validation_datagen, 
                    epochs=EPOCHS,
                    callbacks=[reduce_lr, stop, checkpoint],
                    workers=THREADS,
                    use_multiprocessing=MULTI_PROCESSING,
                    shuffle=True,
                    verbose=1)
# Out:
# Epoch 1/500
# 1425/1425 [==============================] - 890s 624ms/step - loss: 11.5121 - acc: 0.8985 - IOU: 0.7747 - val_loss: 9.3291 - val_acc: 0.9142 - val_IOU: 0.8104
#
# Epoch 00001: val_IOU improved from -inf to 0.81037, saving model to resnext-0.81.h5
# Epoch 2/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 7.9067 - acc: 0.9227 - IOU: 0.8425 - val_loss: 8.0232 - val_acc: 0.9300 - val_IOU: 0.8156
#
# Epoch 00002: val_IOU improved from 0.81037 to 0.81555, saving model to resnext-0.82.h5
# Epoch 3/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 6.9844 - acc: 0.9304 - IOU: 0.8610 - val_loss: 6.1342 - val_acc: 0.9442 - val_IOU: 0.8772
#
# Epoch 00003: val_IOU improved from 0.81555 to 0.87716, saving model to resnext-0.88.h5
# Epoch 4/500
# 1425/1425 [==============================] - 869s 610ms/step - loss: 6.2738 - acc: 0.9359 - IOU: 0.8767 - val_loss: 5.7214 - val_acc: 0.9358 - val_IOU: 0.8726
#
# Epoch 00004: val_IOU did not improve from 0.87716
# Epoch 5/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 5.9085 - acc: 0.9370 - IOU: 0.8828 - val_loss: 6.0153 - val_acc: 0.9375 - val_IOU: 0.8672
#
# Epoch 00005: val_IOU did not improve from 0.87716
# Epoch 6/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 5.5737 - acc: 0.9408 - IOU: 0.8898 - val_loss: 5.8005 - val_acc: 0.9433 - val_IOU: 0.8767
#
# Epoch 00006: val_IOU did not improve from 0.87716
# Epoch 7/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 5.3537 - acc: 0.9426 - IOU: 0.8944 - val_loss: 5.3944 - val_acc: 0.9425 - val_IOU: 0.8946
#
# Epoch 00007: val_IOU improved from 0.87716 to 0.89457, saving model to resnext-0.89.h5
# Epoch 8/500
# 1425/1425 [==============================] - 869s 610ms/step - loss: 5.0512 - acc: 0.9448 - IOU: 0.9004 - val_loss: 5.5338 - val_acc: 0.9400 - val_IOU: 0.8738
#
# Epoch 00008: val_IOU did not improve from 0.89457
# Epoch 9/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 4.9733 - acc: 0.9446 - IOU: 0.9019 - val_loss: 5.4487 - val_acc: 0.9400 - val_IOU: 0.8941
#
# Epoch 00009: val_IOU did not improve from 0.89457
# Epoch 10/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 4.8273 - acc: 0.9457 - IOU: 0.9048 - val_loss: 4.9257 - val_acc: 0.9433 - val_IOU: 0.9002
#
# Epoch 00010: val_IOU improved from 0.89457 to 0.90018, saving model to resnext-0.90.h5
# Epoch 11/500
# 1425/1425 [==============================] - 870s 610ms/step - loss: 4.6027 - acc: 0.9480 - IOU: 0.9085 - val_loss: 5.0568 - val_acc: 0.9517 - val_IOU: 0.9029
#
# Epoch 00011: val_IOU improved from 0.90018 to 0.90294, saving model to resnext-0.90.h5
# Epoch 12/500
# 1425/1425 [==============================] - 869s 610ms/step - loss: 4.5331 - acc: 0.9487 - IOU: 0.9098 - val_loss: 4.7827 - val_acc: 0.9383 - val_IOU: 0.9049
#
# Epoch 00012: val_IOU improved from 0.90294 to 0.90487, saving model to resnext-0.90.h5
# Epoch 13/500
# 1425/1425 [==============================] - 869s 610ms/step - loss: 4.4266 - acc: 0.9499 - IOU: 0.9122 - val_loss: 4.8362 - val_acc: 0.9475 - val_IOU: 0.9054
#
# Epoch 00013: val_IOU improved from 0.90487 to 0.90536, saving model to resnext-0.91.h5
# Epoch 14/500
# 1425/1425 [==============================] - 870s 610ms/step - loss: 4.2775 - acc: 0.9491 - IOU: 0.9153 - val_loss: 4.7862 - val_acc: 0.9475 - val_IOU: 0.9070
#
# Epoch 00014: val_IOU improved from 0.90536 to 0.90695, saving model to resnext-0.91.h5
# Epoch 15/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 4.2628 - acc: 0.9513 - IOU: 0.9157 - val_loss: 4.3432 - val_acc: 0.9558 - val_IOU: 0.9123
#
# Epoch 00015: val_IOU improved from 0.90695 to 0.91228, saving model to resnext-0.91.h5
# Epoch 16/500
# 1425/1425 [==============================] - 870s 610ms/step - loss: 4.1492 - acc: 0.9520 - IOU: 0.9175 - val_loss: 4.3012 - val_acc: 0.9567 - val_IOU: 0.9120
#
# Epoch 00016: val_IOU did not improve from 0.91228
# Epoch 17/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 4.0073 - acc: 0.9552 - IOU: 0.9202 - val_loss: 4.8228 - val_acc: 0.9550 - val_IOU: 0.9032
#
# Epoch 00017: val_IOU did not improve from 0.91228
# Epoch 18/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 4.0408 - acc: 0.9526 - IOU: 0.9192 - val_loss: 5.0581 - val_acc: 0.9550 - val_IOU: 0.8997
#
# Epoch 00018: val_IOU did not improve from 0.91228
# Epoch 19/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 3.9277 - acc: 0.9562 - IOU: 0.9218 - val_loss: 4.0485 - val_acc: 0.9433 - val_IOU: 0.9188
#
# Epoch 00019: val_IOU improved from 0.91228 to 0.91882, saving model to resnext-0.92.h5
# Epoch 20/500
# 1425/1425 [==============================] - 869s 610ms/step - loss: 3.8865 - acc: 0.9542 - IOU: 0.9225 - val_loss: 4.2841 - val_acc: 0.9458 - val_IOU: 0.9160
#
# Epoch 00020: val_IOU did not improve from 0.91882
# Epoch 21/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 3.7779 - acc: 0.9568 - IOU: 0.9242 - val_loss: 3.8707 - val_acc: 0.9567 - val_IOU: 0.9175
#
# Epoch 00021: val_IOU did not improve from 0.91882
# Epoch 22/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 3.7448 - acc: 0.9564 - IOU: 0.9250 - val_loss: 3.9957 - val_acc: 0.9467 - val_IOU: 0.9196
#
# Epoch 00022: val_IOU improved from 0.91882 to 0.91961, saving model to resnext-0.92.h5
# Epoch 23/500
# 1425/1425 [==============================] - 869s 610ms/step - loss: 3.7789 - acc: 0.9560 - IOU: 0.9244 - val_loss: 3.9139 - val_acc: 0.9567 - val_IOU: 0.9229
#
# Epoch 00023: val_IOU improved from 0.91961 to 0.92286, saving model to resnext-0.92.h5
# Epoch 24/500
# 1425/1425 [==============================] - 869s 610ms/step - loss: 3.6329 - acc: 0.9558 - IOU: 0.9276 - val_loss: 3.9734 - val_acc: 0.9533 - val_IOU: 0.9211
#
# Epoch 00024: val_IOU did not improve from 0.92286
# Epoch 25/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 3.6162 - acc: 0.9577 - IOU: 0.9273 - val_loss: 4.1166 - val_acc: 0.9508 - val_IOU: 0.9134
#
# Epoch 00025: val_IOU did not improve from 0.92286
# Epoch 26/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 3.6156 - acc: 0.9565 - IOU: 0.9272 - val_loss: 4.0485 - val_acc: 0.9517 - val_IOU: 0.9219
#
# Epoch 00026: val_IOU did not improve from 0.92286
# Epoch 27/500
# 1425/1425 [==============================] - 870s 610ms/step - loss: 3.4996 - acc: 0.9582 - IOU: 0.9298 - val_loss: 4.2538 - val_acc: 0.9517 - val_IOU: 0.9096
#
# Epoch 00027: val_IOU did not improve from 0.92286
# Epoch 28/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 3.5384 - acc: 0.9564 - IOU: 0.9292 - val_loss: 4.1624 - val_acc: 0.9475 - val_IOU: 0.9197
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00028: val_IOU did not improve from 0.92286
# Epoch 29/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 2.9559 - acc: 0.9610 - IOU: 0.9417 - val_loss: 3.3701 - val_acc: 0.9583 - val_IOU: 0.9345
#
# Epoch 00029: val_IOU improved from 0.92286 to 0.93451, saving model to resnext-0.93.h5
# Epoch 30/500
# 1425/1425 [==============================] - 870s 610ms/step - loss: 2.8655 - acc: 0.9645 - IOU: 0.9438 - val_loss: 3.4084 - val_acc: 0.9600 - val_IOU: 0.9344
#
# Epoch 00030: val_IOU did not improve from 0.93451
# Epoch 31/500
# 1425/1425 [==============================] - 870s 610ms/step - loss: 2.7946 - acc: 0.9649 - IOU: 0.9453 - val_loss: 3.3062 - val_acc: 0.9600 - val_IOU: 0.9357
#
# Epoch 00031: val_IOU improved from 0.93451 to 0.93574, saving model to resnext-0.94.h5
# Epoch 32/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 2.7645 - acc: 0.9650 - IOU: 0.9458 - val_loss: 3.3956 - val_acc: 0.9633 - val_IOU: 0.9334
#
# Epoch 00032: val_IOU did not improve from 0.93574
# Epoch 33/500
# 1425/1425 [==============================] - 873s 613ms/step - loss: 2.7020 - acc: 0.9654 - IOU: 0.9468 - val_loss: 3.3709 - val_acc: 0.9650 - val_IOU: 0.9353
#
# Epoch 00033: val_IOU did not improve from 0.93574
# Epoch 34/500
#
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.6768 - acc: 0.9662 - IOU: 0.9470 - val_loss: 3.3321 - val_acc: 0.9592 - val_IOU: 0.9348
#
# Epoch 00034: val_IOU did not improve from 0.93574
# Epoch 35/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 2.6311 - acc: 0.9657 - IOU: 0.9477 - val_loss: 3.3939 - val_acc: 0.9575 - val_IOU: 0.9317
#
# Epoch 00035: val_IOU did not improve from 0.93574
# Epoch 36/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.5970 - acc: 0.9665 - IOU: 0.9482 - val_loss: 3.2603 - val_acc: 0.9642 - val_IOU: 0.9361
#
# Epoch 00036: val_IOU improved from 0.93574 to 0.93606, saving model to resnext-0.94.h5
# Epoch 37/500
# 1425/1425 [==============================] - 869s 610ms/step - loss: 2.5698 - acc: 0.9663 - IOU: 0.9487 - val_loss: 3.2212 - val_acc: 0.9650 - val_IOU: 0.9359
#
# Epoch 00036: val_IOU improved from 0.93574 to 0.93606, saving model to resnext-0.94.h5
#
# Epoch 00037: val_IOU did not improve from 0.93606
# Epoch 38/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.5464 - acc: 0.9674 - IOU: 0.9491 - val_loss: 3.2592 - val_acc: 0.9617 - val_IOU: 0.9366
#
# Epoch 00038: val_IOU improved from 0.93606 to 0.93662, saving model to resnext-0.94.h5
# Epoch 39/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.5179 - acc: 0.9679 - IOU: 0.9496 - val_loss: 3.2459 - val_acc: 0.9667 - val_IOU: 0.9362
#
# Epoch 00039: val_IOU did not improve from 0.93662
# Epoch 40/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 2.4822 - acc: 0.9681 - IOU: 0.9502 - val_loss: 3.3095 - val_acc: 0.9675 - val_IOU: 0.9359
#
# Epoch 00040: val_IOU did not improve from 0.93662
# Epoch 41/500
# 1425/1425 [==============================] - 872s 612ms/step - loss: 2.4744 - acc: 0.9669 - IOU: 0.9505 - val_loss: 3.3105 - val_acc: 0.9642 - val_IOU: 0.9360
#
# Epoch 00041: val_IOU did not improve from 0.93662
# Epoch 42/500
# 1425/1425 [==============================] - 872s 612ms/step - loss: 2.4513 - acc: 0.9686 - IOU: 0.9505 - val_loss: 3.2092 - val_acc: 0.9617 - val_IOU: 0.9373
#
# Epoch 00042: val_IOU improved from 0.93662 to 0.93731, saving model to resnext-0.94.h5
# Epoch 43/500
# 1425/1425 [==============================] - 869s 610ms/step - loss: 2.4304 - acc: 0.9686 - IOU: 0.9509 - val_loss: 3.1089 - val_acc: 0.9675 - val_IOU: 0.9385
#
# Epoch 00043: val_IOU improved from 0.93731 to 0.93852, saving model to resnext-0.94.h5
# Epoch 44/500
# 1425/1425 [==============================] - 870s 610ms/step - loss: 2.4190 - acc: 0.9683 - IOU: 0.9511 - val_loss: 3.2301 - val_acc: 0.9658 - val_IOU: 0.9358
#
# Epoch 00044: val_IOU did not improve from 0.93852
# Epoch 45/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.3877 - acc: 0.9687 - IOU: 0.9517 - val_loss: 3.1744 - val_acc: 0.9683 - val_IOU: 0.9369
#
# Epoch 00045: val_IOU did not improve from 0.93852
# Epoch 46/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.3622 - acc: 0.9696 - IOU: 0.9521 - val_loss: 3.0963 - val_acc: 0.9650 - val_IOU: 0.9390
#
# Epoch 00046: val_IOU improved from 0.93852 to 0.93897, saving model to resnext-0.94.h5
# Epoch 47/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.3535 - acc: 0.9688 - IOU: 0.9522 - val_loss: 3.2382 - val_acc: 0.9708 - val_IOU: 0.9373
#
# Epoch 00047: val_IOU did not improve from 0.93897
# Epoch 48/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.3430 - acc: 0.9702 - IOU: 0.9523 - val_loss: 3.1590 - val_acc: 0.9650 - val_IOU: 0.9366
#
# Epoch 00048: val_IOU did not improve from 0.93897
# Epoch 49/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.3328 - acc: 0.9696 - IOU: 0.9527 - val_loss: 3.1631 - val_acc: 0.9667 - val_IOU: 0.9366
#
# Epoch 00049: val_IOU did not improve from 0.93897
# Epoch 50/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.3135 - acc: 0.9688 - IOU: 0.9530 - val_loss: 3.2612 - val_acc: 0.9683 - val_IOU: 0.9354
#
# Epoch 00050: val_IOU did not improve from 0.93897
# Epoch 51/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.2795 - acc: 0.9702 - IOU: 0.9535 - val_loss: 3.1006 - val_acc: 0.9658 - val_IOU: 0.9394
#
# Epoch 00051: val_IOU improved from 0.93897 to 0.93938, saving model to resnext-0.94.h5
# Epoch 52/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 2.2567 - acc: 0.9703 - IOU: 0.9538 - val_loss: 3.2900 - val_acc: 0.9692 - val_IOU: 0.9347
#
# Epoch 00051: val_IOU improved from 0.93897 to 0.93938, saving model to resnext-0.94.h5
#
# Epoch 00052: val_IOU did not improve from 0.93938
# Epoch 53/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.2552 - acc: 0.9695 - IOU: 0.9541 - val_loss: 3.2331 - val_acc: 0.9642 - val_IOU: 0.9370
#
# Epoch 00053: val_IOU did not improve from 0.93938
# Epoch 54/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 2.2104 - acc: 0.9698 - IOU: 0.9545 - val_loss: 3.0833 - val_acc: 0.9700 - val_IOU: 0.9392
#
# Epoch 00054: val_IOU did not improve from 0.93938
# Epoch 55/500
#
# Epoch 00053: val_IOU did not improve from 0.93938
# Epoch 54/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 2.2152 - acc: 0.9700 - IOU: 0.9544 - val_loss: 3.2124 - val_acc: 0.9625 - val_IOU: 0.9376
#
# Epoch 00055: val_IOU did not improve from 0.93938
# Epoch 56/500
# 1425/1425 [==============================] - 872s 612ms/step - loss: 2.1858 - acc: 0.9702 - IOU: 0.9551 - val_loss: 3.0962 - val_acc: 0.9700 - val_IOU: 0.9386
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 00056: val_IOU did not improve from 0.93938
# Epoch 57/500
# 1425/1425 [==============================] - 874s 614ms/step - loss: 2.0812 - acc: 0.9708 - IOU: 0.9572 - val_loss: 3.0793 - val_acc: 0.9692 - val_IOU: 0.9401
#
# Epoch 00057: val_IOU improved from 0.93938 to 0.94006, saving model to resnext-0.94.h5
# Epoch 58/500
# 1425/1425 [==============================] - 873s 613ms/step - loss: 2.0764 - acc: 0.9714 - IOU: 0.9573 - val_loss: 3.0744 - val_acc: 0.9717 - val_IOU: 0.9399
#
# Epoch 00058: val_IOU did not improve from 0.94006
# Epoch 59/500
# 1425/1425 [==============================] - 874s 613ms/step - loss: 2.0401 - acc: 0.9720 - IOU: 0.9579 - val_loss: 3.0669 - val_acc: 0.9692 - val_IOU: 0.9399
#
# Epoch 00059: val_IOU did not improve from 0.94006
# Epoch 60/500
#
# Epoch 00058: val_IOU did not improve from 0.94006
# Epoch 59/500
# 1425/1425 [==============================] - 875s 614ms/step - loss: 2.0250 - acc: 0.9714 - IOU: 0.9581 - val_loss: 3.0659 - val_acc: 0.9692 - val_IOU: 0.9399
#
# Epoch 00060: val_IOU did not improve from 0.94006
# Epoch 61/500
# 1425/1425 [==============================] - 874s 613ms/step - loss: 2.0237 - acc: 0.9715 - IOU: 0.9582 - val_loss: 3.0924 - val_acc: 0.9700 - val_IOU: 0.9401
#
# Epoch 00061: val_IOU improved from 0.94006 to 0.94012, saving model to resnext-0.94.h5
# Epoch 62/500
# 1425/1425 [==============================] - 873s 612ms/step - loss: 2.0122 - acc: 0.9712 - IOU: 0.9581 - val_loss: 3.0539 - val_acc: 0.9717 - val_IOU: 0.9403
#
# Epoch 00062: val_IOU improved from 0.94012 to 0.94029, saving model to resnext-0.94.h5
# Epoch 63/500
# 1425/1425 [==============================] - 874s 613ms/step - loss: 2.0021 - acc: 0.9721 - IOU: 0.9585 - val_loss: 3.0704 - val_acc: 0.9692 - val_IOU: 0.9401
#
# Epoch 00063: val_IOU did not improve from 0.94029
# Epoch 64/500
# 1425/1425 [==============================] - 875s 614ms/step - loss: 1.9836 - acc: 0.9722 - IOU: 0.9587 - val_loss: 3.0743 - val_acc: 0.9708 - val_IOU: 0.9397
#
# Epoch 00064: val_IOU did not improve from 0.94029
# Epoch 65/500
# 1425/1425 [==============================] - 873s 613ms/step - loss: 1.9795 - acc: 0.9724 - IOU: 0.9587 - val_loss: 3.0741 - val_acc: 0.9683 - val_IOU: 0.9401
#
# Epoch 00065: val_IOU did not improve from 0.94029
# Epoch 66/500
# 1425/1425 [==============================] - 875s 614ms/step - loss: 1.9693 - acc: 0.9726 - IOU: 0.9592 - val_loss: 3.0570 - val_acc: 0.9667 - val_IOU: 0.9404
#
# Epoch 00066: val_IOU improved from 0.94029 to 0.94045, saving model to resnext-0.94.h5
# Epoch 67/500
# 1425/1425 [==============================] - 873s 612ms/step - loss: 1.9753 - acc: 0.9727 - IOU: 0.9591 - val_loss: 3.0557 - val_acc: 0.9708 - val_IOU: 0.9406
#
# Epoch 00067: val_IOU improved from 0.94045 to 0.94060, saving model to resnext-0.94.h5
# Epoch 68/500
# 1425/1425 [==============================] - 873s 612ms/step - loss: 1.9644 - acc: 0.9732 - IOU: 0.9593 - val_loss: 3.0691 - val_acc: 0.9725 - val_IOU: 0.9404
#
# Epoch 00068: val_IOU did not improve from 0.94060
# Epoch 69/500
# 1425/1425 [==============================] - 876s 614ms/step - loss: 1.9496 - acc: 0.9720 - IOU: 0.9594 - val_loss: 3.0583 - val_acc: 0.9708 - val_IOU: 0.9403
#
# Epoch 00069: val_IOU did not improve from 0.94060
# Epoch 70/500
# 1425/1425 [==============================] - 875s 614ms/step - loss: 1.9264 - acc: 0.9725 - IOU: 0.9597 - val_loss: 3.0512 - val_acc: 0.9683 - val_IOU: 0.9407
#
# Epoch 00070: val_IOU improved from 0.94060 to 0.94074, saving model to resnext-0.94.h5
# Epoch 71/500
# 1425/1425 [==============================] - 872s 612ms/step - loss: 1.9258 - acc: 0.9718 - IOU: 0.9597 - val_loss: 3.0412 - val_acc: 0.9675 - val_IOU: 0.9409
#
# Epoch 00071: val_IOU improved from 0.94074 to 0.94090, saving model to resnext-0.94.h5
# Epoch 72/500
# 1425/1425 [==============================] - 870s 611ms/step - loss: 1.9392 - acc: 0.9730 - IOU: 0.9595 - val_loss: 3.0753 - val_acc: 0.9700 - val_IOU: 0.9404
#
# Epoch 00071: val_IOU improved from 0.94074 to 0.94090, saving model to resnext-0.94.h5
# Epoch 00072: val_IOU did not improve from 0.94090
# Epoch 73/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 1.9219 - acc: 0.9719 - IOU: 0.9599 - val_loss: 3.0765 - val_acc: 0.9708 - val_IOU: 0.9402
#
# Epoch 00073: val_IOU did not improve from 0.94090
# Epoch 74/500
# 1425/1425 [==============================] - 872s 612ms/step - loss: 1.9135 - acc: 0.9726 - IOU: 0.9599 - val_loss: 3.0541 - val_acc: 0.9683 - val_IOU: 0.9405
#
# Epoch 00073: val_IOU did not improve from 0.94090
# Epoch 74/500
#
# Epoch 00074: val_IOU did not improve from 0.94090
# Epoch 75/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 1.9051 - acc: 0.9739 - IOU: 0.9601 - val_loss: 3.0564 - val_acc: 0.9700 - val_IOU: 0.9405
#
# Epoch 00075: val_IOU did not improve from 0.94090
# Epoch 76/500
# 1425/1425 [==============================] - 871s 611ms/step - loss: 1.9094 - acc: 0.9736 - IOU: 0.9601 - val_loss: 3.0798 - val_acc: 0.9700 - val_IOU: 0.9405
# 1425/1425 [==============================] - 871s 611ms/step - loss: 1.9051 - acc: 0.9739 - IOU: 0.9601 - val_loss: 3.0564 - val_acc: 0.9700 - val_IOU: 0.9405
#
# Epoch 00075: val_IOU did not improve from 0.94090
# Epoch 76/500
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 00076: val_IOU did not improve from 0.94090
# Epoch 77/500
# 1425/1425 [==============================] - 874s 613ms/step - loss: 1.8894 - acc: 0.9728 - IOU: 0.9605 - val_loss: 3.0502 - val_acc: 0.9700 - val_IOU: 0.9407
#
# Epoch 00077: val_IOU did not improve from 0.94090
# Epoch 78/500
#
# 1425/1425 [==============================] - 874s 614ms/step - loss: 1.8767 - acc: 0.9737 - IOU: 0.9607 - val_loss: 3.0487 - val_acc: 0.9700 - val_IOU: 0.9408
#
# Epoch 00078: val_IOU did not improve from 0.94090
# Epoch 79/500
#  178/1425 [==>...........................] - ETA: 12:45 - loss: 1.9516 - acc: 0.9756 - IOU: 0.9584
# Process ForkPoolWorker-2520:
# Process ForkPoolWorker-2519:
# Process ForkPoolWorker-2524:
# Process ForkPoolWorker-2513:
# Process ForkPoolWorker-2528:
# Process ForkPoolWorker-2523:
# Process ForkPoolWorker-2512:
# Process ForkPoolWorker-2516:
# Process ForkPoolWorker-2507:
# Process ForkPoolWorker-2500:
# Process ForkPoolWorker-2505:
# Process ForkPoolWorker-2515:
# Process ForkPoolWorker-2504:
# Process ForkPoolWorker-2521:
# Process ForkPoolWorker-2517:
# Process ForkPoolWorker-2526:
# Process ForkPoolWorker-2527:
# Process ForkPoolWorker-2499:
# Process ForkPoolWorker-2506:
# Traceback (most recent call last):
# Process ForkPoolWorker-2514:
# Process ForkPoolWorker-2511:
# Traceback (most recent call last):
# Process ForkPoolWorker-2509:
# Process ForkPoolWorker-2498:
# Process ForkPoolWorker-2525:
# Process ForkPoolWorker-2502:
# Process ForkPoolWorker-2510:
# Process ForkPoolWorker-2497:
# Process ForkPoolWorker-2522:
# Process ForkPoolWorker-2508:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-2503:
# Traceback (most recent call last):
# Process ForkPoolWorker-2501:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-2518:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 349, in put
#     obj = ForkingPickler.dumps(obj)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/reduction.py", line 50, in dumps
#     cls(buf, protocol).dump(obj)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ddf1a5ca1330> in <module>
#       6                     use_multiprocessing=MULTI_PROCESSING,
#       7                     shuffle=True,
# ----> 8                     verbose=1)
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.2.4-py3.5.egg/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.2.4-py3.5.egg/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1451             use_multiprocessing=use_multiprocessing,
#    1452             shuffle=shuffle,
# -> 1453             initial_epoch=initial_epoch)
#    1454
#    1455     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.2.4-py3.5.egg/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     213                 outs = model.train_on_batch(x, y,
#     214                                             sample_weight=sample_weight,
# --> 215                                             class_weight=class_weight)
#     216
#     217                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.2.4-py3.5.egg/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1242             ins = x + y + sample_weights
#    1243         self._make_train_function()
# -> 1244         outputs = self.train_function(ins)
#    1245         return unpack_singleton(outputs)
#    1246
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.2.4-py3.5.egg/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2923                     return self._legacy_call(inputs)
#    2924
# -> 2925             return self._call(inputs)
#    2926         else:
#    2927             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.2.4-py3.5.egg/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2881             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2882         else:
# -> 2883             fetched = self._callable_fn(*array_vals)
#    2884         return fetched[:len(self.outputs)]
#    2885
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# After training, we need to load weights from the best validation IoU file we got, and then make predictions on the test data set.

# %%
## Since the models will take a huge amount of time to train, you can download the trained weights from 
## this Google Drive folder into the directory
## https://drive.google.com/drive/folders/1rOVkxqHaCKjamji7c3XfdomvMbqksgU6?usp=sharing

WEIGHTS_FILE = "resnext-0.94.h5"

resnx.load_weights(WEIGHTS_FILE)

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#                                image_name  x1  x2  y1  y2
# 0               1467891670691DSC_0582.png NaN NaN NaN NaN
# 1               1475151786691DSC00560.png NaN NaN NaN NaN
# 2               1480334114405_R2A3620.png NaN NaN NaN NaN
# 3  JPEG_20160712_161047_1000606860114.png NaN NaN NaN NaN
# 4    JPEG_20160403_174522_-1137349501.png NaN NaN NaN NaN

# %%
for index, row in test.iterrows():
    unscaled = cv2.imread(DATA_DIR+row['image_name'])
    image_height, image_width, _ = unscaled.shape

    image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE))
    feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

    region = resnx.predict(x=np.array([feat_scaled]))[0]

    x1 = (region[0] * image_width / IMAGE_SIZE)
    y1 = (region[1] * image_height / IMAGE_SIZE)

    x2 = ((region[0] + region[2]) * image_width / IMAGE_SIZE)
    y2 = ((region[1] + region[3]) * image_height / IMAGE_SIZE)

    test.iloc[index,1] = x1
    test.iloc[index,2] = x2
    test.iloc[index,3] = y1
    test.iloc[index,4] = y2
    
    if index%1000==0:
        print(index)

test.head()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
#                                image_name          x1          x2          y1  \
# 0               1467891670691DSC_0582.png   79.025781  557.109288   87.194039
# 1               1475151786691DSC00560.png  234.738813  410.301383  120.170100
# 2               1480334114405_R2A3620.png  196.482435  428.911394   97.357325
# 3  JPEG_20160712_161047_1000606860114.png  186.538217  507.632839   58.885583
# 4    JPEG_20160403_174522_-1137349501.png   89.006478  524.121791   58.543371
#
#            y2
# 0  430.638330
# 1  417.912434
# 2  369.242870
# 3  411.968209
# 4  379.296799

# %%
test.to_csv('resnx-prediction.csv', index=False)

# %% [markdown]
# Since we also require predictions on the complete training and validation set, we will also create and save CSV files for both.

# %%
train = pd.read_csv("training_set.csv")

for index, row in train.iterrows():
    unscaled = cv2.imread(DATA_DIR+row['image_name'])
    image_height, image_width, _ = unscaled.shape

    image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE))
    feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

    region = resnx.predict(x=np.array([feat_scaled]))[0]

    x1 = (region[0] * image_width / IMAGE_SIZE)
    y1 = (region[1] * image_height / IMAGE_SIZE)

    x2 = ((region[0] + region[2]) * image_width / IMAGE_SIZE)
    y2 = ((region[1] + region[3]) * image_height / IMAGE_SIZE)

    train.iloc[index,1] = x1
    train.iloc[index,2] = x2
    train.iloc[index,3] = y1
    train.iloc[index,4] = y2
    
    if index%1000==0:
        print(index)
    
train.to_csv('resnx-training.csv', index=False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
